# %%
import pandas as pd

# Load the uploaded files
true_df = pd.read_excel('TS_True_All_Goals_Chances.xlsx')
false_df = pd.read_excel('TS_False_All_Goals_Chances.xlsx')
all_df = pd.read_excel('All_Goals_Chances.xlsx')
# Out:
# /Users/henrymckinney/opt/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# Define critical shot types
critical_shot_types = [
    "Defensive Screen", "High Slot Line Pass", "Layered Screen", "Mid % Broken Play	", "Low Slot Line Pass",
    "Breakaway", "Half-Ice Breakaway", "CS Odd Man Rush Slot",
    "Behind the Net To Slot One Timer", "Slot Line Double", "Deflection On Ice", "CS Broken Play",
    "One Timer Outside Slot Area", "Partial Breakaway"
]

# %%
print("All_Goals_Chances Data")
all_df = all_df.round(2) 
all_df = all_df.sort_values("Shooting Percent", ascending=False)
all_df
# Out:
# All_Goals_Chances Data
#                                           Chance Type  All Chances  Goals  \
# 13                                       Goalie Error         45.0   27.0
# 32                                   Slot Line Double        302.0  154.0
# 39                                Weak High % Rebound         13.0  148.0
# 41                              Weak Net Play Rebound          1.0   13.0
# 27                                 Passed Off Rebound          5.0   43.0
# 40                                 Weak Mid % Rebound         21.0  165.0
# 15                                 High % Broken Play       1071.0  446.0
# 19                                 Low Slot Line Pass       1932.0  622.0
# 28                                 Screened One Timer        534.0  158.0
# 38                           Weak Clear Sight Rebound          6.0   63.0
# 30                                   Slot Area Screen        652.0  180.0
# 2                                           Breakaway        659.0  181.0
# 26                                  Partial Breakaway        891.0  218.0
# 20                                  Mid % Broken Play       1780.0  396.0
# 1                    Behind the Net To Slot One Timer        408.0   82.0
# 5                                CS Odd Man Rush Slot        718.0  133.0
# 29                                Screened/Deflection        913.0  154.0
# 31                                    Slot Line Carry        369.0   58.0
# 17                                High Slot Line Pass       1580.0  247.0
# 18                                     Layered Screen       1297.0  175.0
# 3                                     BTN Broken Play         57.0    8.0
# 11                                  Deflection In Air        888.0  113.0
# 21                                    Net Broken Play        292.0   33.0
# 9                                   CS Time And Space        757.0   94.0
# 14                                 Half-Ice Breakaway        594.0   69.0
# 4                                      CS Broken Play        833.0   92.0
# 33                                     Slot One Timer       2030.0  214.0
# 35                              Strong High % Rebound         62.0   45.0
# 24                             One Timer / Deflection         66.0    6.0
# 37                            Strong Net Play Rebound         12.0    9.0
# 36                               Strong Mid % Rebound         75.0   58.0
# 10                                   Defensive Screen       1126.0   86.0
# 23                                   Offensive Screen       1191.0   45.0
# 25                        One Timer Outside Slot Area       1748.0   63.0
# 12                                  Deflection On Ice        902.0   34.0
# 34                         Strong Clear Sight Rebound         42.0   16.0
# 8                                        CS Slot Area       2786.0   87.0
# 0                                      Behind the Net        326.0   10.0
# 22                                           Net Play       1555.0   27.0
# 6                                CS Outside Slot Area      10153.0  150.0
# 16                                     High One Timer       2213.0   16.0
# 7                                        CS Perimeter       4808.0   11.0
# 42                                                NaN          NaN    NaN
# 43  Applied filters:\nLineageReportShotCat is not ...          NaN    NaN
#
#     Expected Goals  Goals Diff Toggle  Shooting Percent  Historical %
# 13            0.42              26.58              0.64          0.01
# 32          139.65              14.35              0.54          0.49
# 39          157.76              -9.76              0.54          0.58
# 41            5.67               7.33              0.48          0.21
# 27           55.00             -12.00              0.43          0.55
# 40          175.33             -10.33              0.42          0.44
# 15          458.25             -12.25              0.38          0.39
# 19          643.62             -21.62              0.34          0.36
# 28          167.96              -9.96              0.32          0.34
# 38           56.00               7.00              0.32          0.28
# 30          180.54              -0.54              0.29          0.30
# 2           195.30             -14.30              0.29          0.32
# 26          191.63              26.37              0.26          0.23
# 20          436.74             -40.74              0.23          0.26
# 1            74.00               8.00              0.22          0.20
# 5           144.54             -11.54              0.20          0.22
# 29          188.83             -34.83              0.19          0.23
# 31           67.00              -9.00              0.17          0.20
# 17          300.60             -53.60              0.16          0.20
# 18          220.71             -45.71              0.15          0.18
# 3             7.15               0.85              0.15          0.13
# 11          120.09              -7.09              0.14          0.15
# 21           31.12               1.88              0.13          0.12
# 9            69.44              24.56              0.13          0.10
# 14           82.14             -13.14              0.13          0.15
# 4            76.10              15.90              0.12          0.10
# 33          223.96              -9.96              0.11          0.12
# 35           46.42              -1.42              0.11          0.11
# 24           14.50              -8.50              0.10          0.25
# 37            7.95               1.05              0.08          0.07
# 36           62.35              -4.35              0.08          0.09
# 10          153.00             -67.00              0.08          0.15
# 23           41.46               3.54              0.04          0.04
# 25           44.55              18.45              0.04          0.03
# 12           21.45              12.55              0.04          0.03
# 34           17.42              -1.42              0.04          0.04
# 8           108.73             -21.73              0.03          0.04
# 0             4.53               5.47              0.03          0.02
# 22           36.74              -9.74              0.02          0.03
# 6           127.21              22.79              0.02          0.01
# 16           13.78               2.22              0.01          0.01
# 7            10.28               0.72              0.00          0.00
# 42             NaN                NaN               NaN           NaN
# 43             NaN                NaN               NaN           NaN

# %%
# Display the loaded tables
print("TS_True_All_Goals_Chances Data")
true_df = true_df.round(2) 
true_df
# Out:
# TS_True_All_Goals_Chances Data
#                                           Chance Type  All Chances  Goals  \
# 0                                      Behind the Net         38.0    4.0
# 1                    Behind the Net To Slot One Timer        103.0   30.0
# 2                                           Breakaway        448.0  129.0
# 3                                     BTN Broken Play         10.0    2.0
# 4                                      CS Broken Play        214.0   40.0
# 5                                CS Odd Man Rush Slot        463.0  101.0
# 6                                CS Outside Slot Area       2347.0   61.0
# 7                                        CS Perimeter       1636.0    6.0
# 8                                        CS Slot Area         15.0    1.0
# 9                                   CS Time And Space        757.0   94.0
# 10                                   Defensive Screen        494.0   39.0
# 11                                  Deflection In Air        146.0   23.0
# 12                                  Deflection On Ice        124.0    7.0
# 13                                       Goalie Error         14.0   11.0
# 14                                 Half-Ice Breakaway        257.0   40.0
# 15                                 High % Broken Play        214.0   98.0
# 16                                     High One Timer       1547.0   12.0
# 17                                High Slot Line Pass       1028.0  185.0
# 18                                     Layered Screen        731.0  120.0
# 19                                 Low Slot Line Pass        934.0  356.0
# 20                                  Mid % Broken Play        379.0  119.0
# 21                                    Net Broken Play         13.0    5.0
# 22                                           Net Play        120.0    7.0
# 23                                   Offensive Screen        661.0   28.0
# 24                             One Timer / Deflection         16.0    2.0
# 25                        One Timer Outside Slot Area        849.0   40.0
# 26                                  Partial Breakaway        413.0  110.0
# 27                                 Passed Off Rebound          1.0   22.0
# 28                                 Screened One Timer        248.0   89.0
# 29                                Screened/Deflection        104.0   20.0
# 30                                   Slot Area Screen        202.0   79.0
# 31                                    Slot Line Carry         62.0   19.0
# 32                                   Slot Line Double        138.0   91.0
# 33                                     Slot One Timer        631.0   96.0
# 34                              Strong High % Rebound          4.0    8.0
# 35                               Strong Mid % Rebound          1.0    5.0
# 36                                 Weak Mid % Rebound          1.0   35.0
# 37                                                NaN          NaN    NaN
# 38  Applied filters:\nLineageReportShotCat is not ...          NaN    NaN
#
#     Expected Goals  Goals Diff Toggle  Shooting Percent  Historical %
# 0             0.53               3.47              0.11          0.02
# 1            19.20              10.80              0.31          0.20
# 2           133.87              -4.87              0.30          0.32
# 3             1.17               0.83              0.22          0.13
# 4            19.10              20.90              0.21          0.10
# 5            93.06               7.94              0.24          0.22
# 6            29.41              31.59              0.03          0.01
# 7             3.50               2.50              0.00          0.00
# 8             0.57               0.43              0.07          0.04
# 9            69.44              24.56              0.13          0.10
# 10           67.35             -28.35              0.09          0.15
# 11           18.92               4.08              0.18          0.15
# 12            2.94               4.06              0.06          0.03
# 13            0.14              10.86              0.79          0.01
# 14           35.64               4.36              0.17          0.15
# 15           86.58              11.42              0.44          0.39
# 16            9.63               2.37              0.01          0.01
# 17          197.20             -12.20              0.19          0.20
# 18          125.06              -5.06              0.18          0.18
# 19          316.66              39.34              0.40          0.36
# 20           91.90              27.10              0.33          0.26
# 21            1.50               3.50              0.42          0.12
# 22            2.86               4.14              0.06          0.03
# 23           23.22               4.78              0.05          0.04
# 24            3.50              -1.50              0.14          0.25
# 25           21.65              18.35              0.05          0.03
# 26           88.16              21.84              0.29          0.23
# 27           22.00              -0.00              0.55          0.55
# 28           77.86              11.14              0.39          0.34
# 29           20.70              -0.70              0.22          0.23
# 30           56.94              22.06              0.41          0.30
# 31           11.80               7.20              0.32          0.20
# 32           65.17              25.83              0.68          0.49
# 33           70.80              25.20              0.16          0.12
# 34            3.30               4.70              0.27          0.11
# 35            1.55               3.45              0.28          0.09
# 36           24.92              10.08              0.62          0.44
# 37             NaN                NaN               NaN           NaN
# 38             NaN                NaN               NaN           NaN

# %%
print("TS_False_All_Goals_Chances Data")
false_df = false_df.round(2) 
false_df
# Out:
# TS_False_All_Goals_Chances Data
#                                           Chance Type  All Chances  Goals  \
# 0                                      Behind the Net        288.0    6.0
# 1                    Behind the Net To Slot One Timer        305.0   52.0
# 2                                           Breakaway        211.0   52.0
# 3                                     BTN Broken Play         47.0    6.0
# 4                                      CS Broken Play        619.0   52.0
# 5                                CS Odd Man Rush Slot        255.0   32.0
# 6                                CS Outside Slot Area       7806.0   89.0
# 7                                        CS Perimeter       3172.0    5.0
# 8                                        CS Slot Area       2771.0   86.0
# 9                                    Defensive Screen        632.0   47.0
# 10                                  Deflection In Air        742.0   90.0
# 11                                  Deflection On Ice        778.0   27.0
# 12                                       Goalie Error         31.0   16.0
# 13                                 Half-Ice Breakaway        337.0   29.0
# 14                                 High % Broken Play        857.0  348.0
# 15                                     High One Timer        666.0    4.0
# 16                                High Slot Line Pass        552.0   62.0
# 17                                     Layered Screen        566.0   55.0
# 18                                 Low Slot Line Pass        998.0  266.0
# 19                                  Mid % Broken Play       1401.0  277.0
# 20                                    Net Broken Play        279.0   28.0
# 21                                           Net Play       1435.0   20.0
# 22                                   Offensive Screen        530.0   17.0
# 23                             One Timer / Deflection         50.0    4.0
# 24                        One Timer Outside Slot Area        899.0   23.0
# 25                                  Partial Breakaway        478.0  108.0
# 26                                 Passed Off Rebound          4.0   21.0
# 27                                 Screened One Timer        286.0   69.0
# 28                                Screened/Deflection        809.0  134.0
# 29                                   Slot Area Screen        450.0  101.0
# 30                                    Slot Line Carry        307.0   39.0
# 31                                   Slot Line Double        164.0   63.0
# 32                                     Slot One Timer       1399.0  118.0
# 33                         Strong Clear Sight Rebound         42.0   16.0
# 34                              Strong High % Rebound         58.0   37.0
# 35                               Strong Mid % Rebound         74.0   53.0
# 36                            Strong Net Play Rebound         12.0    9.0
# 37                           Weak Clear Sight Rebound          6.0   48.0
# 38                                Weak High % Rebound         13.0  121.0
# 39                                 Weak Mid % Rebound         20.0  130.0
# 40                              Weak Net Play Rebound          1.0   10.0
# 41                                                NaN          NaN    NaN
# 42  Applied filters:\nLineageReportShotCat is not ...          NaN    NaN
#
#     Expected Goals  Goals Diff Toggle  Shooting Percent  Historical %
# 0             4.01               1.99              0.02          0.02
# 1            54.80              -2.80              0.19          0.20
# 2            61.42              -9.42              0.27          0.32
# 3             5.98               0.02              0.13          0.13
# 4            57.00              -5.00              0.09          0.10
# 5            51.48             -19.48              0.14          0.22
# 6            97.80              -8.80              0.01          0.01
# 7             6.78              -1.78              0.00          0.00
# 8           108.16             -22.16              0.03          0.04
# 9            85.65             -38.65              0.08          0.15
# 10          101.17             -11.17              0.13          0.15
# 11           18.51               8.49              0.04          0.03
# 12            0.28              15.72              0.57          0.01
# 13           46.51             -17.51              0.09          0.15
# 14          371.67             -23.67              0.37          0.39
# 15            4.15              -0.15              0.01          0.01
# 16          103.40             -41.40              0.12          0.20
# 17           95.65             -40.65              0.11          0.18
# 18          326.96             -60.96              0.29          0.36
# 19          344.83             -67.83              0.21          0.26
# 20           29.62              -1.62              0.12          0.12
# 21           33.88             -13.88              0.02          0.03
# 22           18.24              -1.24              0.04          0.04
# 23           11.00              -7.00              0.09          0.25
# 24           22.90               0.10              0.03          0.03
# 25          103.47               4.53              0.24          0.23
# 26           33.00             -12.00              0.35          0.55
# 27           90.10             -21.10              0.26          0.34
# 28          168.13             -34.13              0.18          0.23
# 29          123.61             -22.61              0.24          0.30
# 30           55.20             -16.20              0.14          0.20
# 31           74.48             -11.48              0.41          0.49
# 32          153.16             -35.16              0.09          0.12
# 33           16.70              -0.70              0.04          0.04
# 34           43.12              -6.12              0.09          0.11
# 35           60.80              -7.80              0.07          0.09
# 36            7.95               1.05              0.08          0.07
# 37           46.20               1.80              0.29          0.28
# 38          136.30             -15.30              0.51          0.58
# 39          150.41             -20.41              0.38          0.44
# 40            4.83               5.17              0.43          0.21
# 41             NaN                NaN               NaN           NaN
# 42             NaN                NaN               NaN           NaN

# %%
# Cell 5: Create shooting percent comparison table
shooting_comparison_df = pd.merge(
    pd.merge(
        all_df[['Chance Type', 'Shooting Percent']],
        true_df[['Chance Type', 'Shooting Percent']],
        on='Chance Type',
        suffixes=('_all', '_TS_True')
    ),
    false_df[['Chance Type', 'Shooting Percent']],
    on='Chance Type'
)
shooting_comparison_df.rename(columns={'Shooting Percent': 'Shooting Percent_TS_False'}, inplace=True)

# Calculate differences
shooting_comparison_df['TS_True_minus_all'] = (
    shooting_comparison_df['Shooting Percent_TS_True'] - shooting_comparison_df['Shooting Percent_all']
)
shooting_comparison_df['TS_True_minus_TS_False'] = (
    shooting_comparison_df['Shooting Percent_TS_True'] - shooting_comparison_df['Shooting Percent_TS_False']
)
shooting_comparison_df['all_minus_TS_False'] = (
    shooting_comparison_df['Shooting Percent_all'] - shooting_comparison_df['Shooting Percent_TS_False']
)

# Round results to 3 decimal places and remove trailing zeros
shooting_comparison_df = shooting_comparison_df.applymap(lambda x: f'{x:.3f}'.rstrip('0').rstrip('.') if isinstance(x, float) else x)

# Highlight critical shot types and specific columns
def highlight_styles(row):
    styles = []
    for col in shooting_comparison_df.columns:
        if row['Chance Type'] in critical_shot_types:
            styles.append('background-color: lightyellow')
        elif col == 'Shooting Percent_TS_True':
            styles.append('background-color: #d4edda')  # light green
        elif col == 'Shooting Percent_TS_False':
            styles.append('background-color: #f8d7da')  # light red
        else:
            styles.append('')
    return styles

styled_df = shooting_comparison_df.style.apply(highlight_styles, axis=1)

# Display the comparison results with highlights
print("Shooting Percent Comparison (Critical Shot Types Highlighted and Column Colors Applied)")
display(styled_df)
# Out:
# Shooting Percent Comparison (Critical Shot Types Highlighted and Column Colors Applied)
# <style type="text/css">
# #T_6c30b_row0_col2, #T_6c30b_row3_col2, #T_6c30b_row6_col2, #T_6c30b_row7_col2, #T_6c30b_row8_col2, #T_6c30b_row10_col2, #T_6c30b_row12_col2, #T_6c30b_row14_col2, #T_6c30b_row15_col2, #T_6c30b_row19_col2, #T_6c30b_row20_col2, #T_6c30b_row21_col2, #T_6c30b_row22_col2, #T_6c30b_row23_col2, #T_6c30b_row26_col2, #T_6c30b_row27_col2, #T_6c30b_row28_col2, #T_6c30b_row29_col2, #T_6c30b_row30_col2, #T_6c30b_row32_col2, #T_6c30b_row33_col2, #T_6c30b_row34_col2, #T_6c30b_row35_col2, #T_6c30b_row36_col2 {
#   background-color: #d4edda;
# }
# #T_6c30b_row0_col3, #T_6c30b_row3_col3, #T_6c30b_row6_col3, #T_6c30b_row7_col3, #T_6c30b_row8_col3, #T_6c30b_row10_col3, #T_6c30b_row12_col3, #T_6c30b_row14_col3, #T_6c30b_row15_col3, #T_6c30b_row19_col3, #T_6c30b_row20_col3, #T_6c30b_row21_col3, #T_6c30b_row22_col3, #T_6c30b_row23_col3, #T_6c30b_row26_col3, #T_6c30b_row27_col3, #T_6c30b_row28_col3, #T_6c30b_row29_col3, #T_6c30b_row30_col3, #T_6c30b_row32_col3, #T_6c30b_row33_col3, #T_6c30b_row34_col3, #T_6c30b_row35_col3, #T_6c30b_row36_col3 {
#   background-color: #f8d7da;
# }
# #T_6c30b_row1_col0, #T_6c30b_row1_col1, #T_6c30b_row1_col2, #T_6c30b_row1_col3, #T_6c30b_row1_col4, #T_6c30b_row1_col5, #T_6c30b_row1_col6, #T_6c30b_row2_col0, #T_6c30b_row2_col1, #T_6c30b_row2_col2, #T_6c30b_row2_col3, #T_6c30b_row2_col4, #T_6c30b_row2_col5, #T_6c30b_row2_col6, #T_6c30b_row4_col0, #T_6c30b_row4_col1, #T_6c30b_row4_col2, #T_6c30b_row4_col3, #T_6c30b_row4_col4, #T_6c30b_row4_col5, #T_6c30b_row4_col6, #T_6c30b_row5_col0, #T_6c30b_row5_col1, #T_6c30b_row5_col2, #T_6c30b_row5_col3, #T_6c30b_row5_col4, #T_6c30b_row5_col5, #T_6c30b_row5_col6, #T_6c30b_row9_col0, #T_6c30b_row9_col1, #T_6c30b_row9_col2, #T_6c30b_row9_col3, #T_6c30b_row9_col4, #T_6c30b_row9_col5, #T_6c30b_row9_col6, #T_6c30b_row11_col0, #T_6c30b_row11_col1, #T_6c30b_row11_col2, #T_6c30b_row11_col3, #T_6c30b_row11_col4, #T_6c30b_row11_col5, #T_6c30b_row11_col6, #T_6c30b_row13_col0, #T_6c30b_row13_col1, #T_6c30b_row13_col2, #T_6c30b_row13_col3, #T_6c30b_row13_col4, #T_6c30b_row13_col5, #T_6c30b_row13_col6, #T_6c30b_row16_col0, #T_6c30b_row16_col1, #T_6c30b_row16_col2, #T_6c30b_row16_col3, #T_6c30b_row16_col4, #T_6c30b_row16_col5, #T_6c30b_row16_col6, #T_6c30b_row17_col0, #T_6c30b_row17_col1, #T_6c30b_row17_col2, #T_6c30b_row17_col3, #T_6c30b_row17_col4, #T_6c30b_row17_col5, #T_6c30b_row17_col6, #T_6c30b_row18_col0, #T_6c30b_row18_col1, #T_6c30b_row18_col2, #T_6c30b_row18_col3, #T_6c30b_row18_col4, #T_6c30b_row18_col5, #T_6c30b_row18_col6, #T_6c30b_row24_col0, #T_6c30b_row24_col1, #T_6c30b_row24_col2, #T_6c30b_row24_col3, #T_6c30b_row24_col4, #T_6c30b_row24_col5, #T_6c30b_row24_col6, #T_6c30b_row25_col0, #T_6c30b_row25_col1, #T_6c30b_row25_col2, #T_6c30b_row25_col3, #T_6c30b_row25_col4, #T_6c30b_row25_col5, #T_6c30b_row25_col6, #T_6c30b_row31_col0, #T_6c30b_row31_col1, #T_6c30b_row31_col2, #T_6c30b_row31_col3, #T_6c30b_row31_col4, #T_6c30b_row31_col5, #T_6c30b_row31_col6 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_6c30b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chance Type</th>
#       <th class="col_heading level0 col1" >Shooting Percent_all</th>
#       <th class="col_heading level0 col2" >Shooting Percent_TS_True</th>
#       <th class="col_heading level0 col3" >Shooting Percent_TS_False</th>
#       <th class="col_heading level0 col4" >TS_True_minus_all</th>
#       <th class="col_heading level0 col5" >TS_True_minus_TS_False</th>
#       <th class="col_heading level0 col6" >all_minus_TS_False</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c30b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c30b_row0_col0" class="data row0 col0" >Behind the Net</td>
#       <td id="T_6c30b_row0_col1" class="data row0 col1" >0.03</td>
#       <td id="T_6c30b_row0_col2" class="data row0 col2" >0.11</td>
#       <td id="T_6c30b_row0_col3" class="data row0 col3" >0.02</td>
#       <td id="T_6c30b_row0_col4" class="data row0 col4" >0.08</td>
#       <td id="T_6c30b_row0_col5" class="data row0 col5" >0.09</td>
#       <td id="T_6c30b_row0_col6" class="data row0 col6" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c30b_row1_col0" class="data row1 col0" >Behind the Net To Slot One Timer</td>
#       <td id="T_6c30b_row1_col1" class="data row1 col1" >0.22</td>
#       <td id="T_6c30b_row1_col2" class="data row1 col2" >0.31</td>
#       <td id="T_6c30b_row1_col3" class="data row1 col3" >0.19</td>
#       <td id="T_6c30b_row1_col4" class="data row1 col4" >0.09</td>
#       <td id="T_6c30b_row1_col5" class="data row1 col5" >0.12</td>
#       <td id="T_6c30b_row1_col6" class="data row1 col6" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c30b_row2_col0" class="data row2 col0" >Breakaway</td>
#       <td id="T_6c30b_row2_col1" class="data row2 col1" >0.29</td>
#       <td id="T_6c30b_row2_col2" class="data row2 col2" >0.3</td>
#       <td id="T_6c30b_row2_col3" class="data row2 col3" >0.27</td>
#       <td id="T_6c30b_row2_col4" class="data row2 col4" >0.01</td>
#       <td id="T_6c30b_row2_col5" class="data row2 col5" >0.03</td>
#       <td id="T_6c30b_row2_col6" class="data row2 col6" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c30b_row3_col0" class="data row3 col0" >BTN Broken Play</td>
#       <td id="T_6c30b_row3_col1" class="data row3 col1" >0.15</td>
#       <td id="T_6c30b_row3_col2" class="data row3 col2" >0.22</td>
#       <td id="T_6c30b_row3_col3" class="data row3 col3" >0.13</td>
#       <td id="T_6c30b_row3_col4" class="data row3 col4" >0.07</td>
#       <td id="T_6c30b_row3_col5" class="data row3 col5" >0.09</td>
#       <td id="T_6c30b_row3_col6" class="data row3 col6" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6c30b_row4_col0" class="data row4 col0" >CS Broken Play</td>
#       <td id="T_6c30b_row4_col1" class="data row4 col1" >0.12</td>
#       <td id="T_6c30b_row4_col2" class="data row4 col2" >0.21</td>
#       <td id="T_6c30b_row4_col3" class="data row4 col3" >0.09</td>
#       <td id="T_6c30b_row4_col4" class="data row4 col4" >0.09</td>
#       <td id="T_6c30b_row4_col5" class="data row4 col5" >0.12</td>
#       <td id="T_6c30b_row4_col6" class="data row4 col6" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6c30b_row5_col0" class="data row5 col0" >CS Odd Man Rush Slot</td>
#       <td id="T_6c30b_row5_col1" class="data row5 col1" >0.2</td>
#       <td id="T_6c30b_row5_col2" class="data row5 col2" >0.24</td>
#       <td id="T_6c30b_row5_col3" class="data row5 col3" >0.14</td>
#       <td id="T_6c30b_row5_col4" class="data row5 col4" >0.04</td>
#       <td id="T_6c30b_row5_col5" class="data row5 col5" >0.1</td>
#       <td id="T_6c30b_row5_col6" class="data row5 col6" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6c30b_row6_col0" class="data row6 col0" >CS Outside Slot Area</td>
#       <td id="T_6c30b_row6_col1" class="data row6 col1" >0.02</td>
#       <td id="T_6c30b_row6_col2" class="data row6 col2" >0.03</td>
#       <td id="T_6c30b_row6_col3" class="data row6 col3" >0.01</td>
#       <td id="T_6c30b_row6_col4" class="data row6 col4" >0.01</td>
#       <td id="T_6c30b_row6_col5" class="data row6 col5" >0.02</td>
#       <td id="T_6c30b_row6_col6" class="data row6 col6" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6c30b_row7_col0" class="data row7 col0" >CS Perimeter</td>
#       <td id="T_6c30b_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_6c30b_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_6c30b_row7_col3" class="data row7 col3" >0</td>
#       <td id

# %%
print(shooting_comparison_df.info())  # Check data types and nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37 entries, 0 to 36
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Chance Type                37 non-null     object
#  1   Shooting Percent_all       37 non-null     object
#  2   Shooting Percent_TS_True   37 non-null     object
#  3   Shooting Percent_TS_False  37 non-null     object
#  4   TS_True_minus_all          37 non-null     object
#  5   TS_True_minus_TS_False     37 non-null     object
#  6   all_minus_TS_False         37 non-null     object
# dtypes: object(7)
# memory usage: 3.4+ KB
# None

# %%
display(shooting_comparison_df)
# Out:
#                          Chance Type Shooting Percent_all  \
# 0                     Behind the Net                 0.03
# 1   Behind the Net To Slot One Timer                 0.22
# 2                          Breakaway                 0.29
# 3                    BTN Broken Play                 0.15
# 4                     CS Broken Play                 0.12
# 5               CS Odd Man Rush Slot                  0.2
# 6               CS Outside Slot Area                 0.02
# 7                       CS Perimeter                    0
# 8                       CS Slot Area                 0.03
# 9                   Defensive Screen                 0.08
# 10                 Deflection In Air                 0.14
# 11                 Deflection On Ice                 0.04
# 12                      Goalie Error                 0.64
# 13                Half-Ice Breakaway                 0.13
# 14                High % Broken Play                 0.38
# 15                    High One Timer                 0.01
# 16               High Slot Line Pass                 0.16
# 17                    Layered Screen                 0.15
# 18                Low Slot Line Pass                 0.34
# 19                 Mid % Broken Play                 0.23
# 20                   Net Broken Play                 0.13
# 21                          Net Play                 0.02
# 22                  Offensive Screen                 0.04
# 23            One Timer / Deflection                  0.1
# 24       One Timer Outside Slot Area                 0.04
# 25                 Partial Breakaway                 0.26
# 26                Passed Off Rebound                 0.43
# 27                Screened One Timer                 0.32
# 28               Screened/Deflection                 0.19
# 29                  Slot Area Screen                 0.29
# 30                   Slot Line Carry                 0.17
# 31                  Slot Line Double                 0.54
# 32                    Slot One Timer                 0.11
# 33             Strong High % Rebound                 0.11
# 34              Strong Mid % Rebound                 0.08
# 35                Weak Mid % Rebound                 0.42
# 36                               nan                  nan
#
#    Shooting Percent_TS_True Shooting Percent_TS_False TS_True_minus_all  \
# 0                      0.11                      0.02              0.08
# 1                      0.31                      0.19              0.09
# 2                       0.3                      0.27              0.01
# 3                      0.22                      0.13              0.07
# 4                      0.21                      0.09              0.09
# 5                      0.24                      0.14              0.04
# 6                      0.03                      0.01              0.01
# 7                         0                         0                 0
# 8                      0.07                      0.03              0.04
# 9                      0.09                      0.08              0.01
# 10                     0.18                      0.13              0.04
# 11                     0.06                      0.04              0.02
# 12                     0.79                      0.57              0.15
# 13                     0.17                      0.09              0.04
# 14                     0.44                      0.37              0.06
# 15                     0.01                      0.01                 0
# 16                     0.19                      0.12              0.03
# 17                     0.18                      0.11              0.03
# 18                      0.4                      0.29              0.06
# 19                     0.33                      0.21               0.1
# 20                     0.42                      0.12              0.29
# 21                     0.06                      0.02              0.04
# 22                     0.05                      0.04              0.01
# 23                     0.14                      0.09              0.04
# 24                     0.05                      0.03              0.01
# 25                     0.29                      0.24              0.03
# 26                     0.55                      0.35              0.12
# 27                     0.39                      0.26              0.07
# 28                     0.22                      0.18              0.03
# 29                     0.41                      0.24              0.12
# 30                     0.32                      0.14              0.15
# 31                     0.68                      0.41              0.14
# 32                     0.16                      0.09              0.05
# 33                     0.27                      0.09              0.16
# 34                     0.28                      0.07               0.2
# 35                     0.62                      0.38               0.2
# 36                      nan                       nan               nan
#
#    TS_True_minus_TS_False all_minus_TS_False
# 0                    0.09               0.01
# 1                    0.12               0.03
# 2                    0.03               0.02
# 3                    0.09               0.02
# 4                    0.12               0.03
# 5                     0.1               0.06
# 6                    0.02               0.01
# 7                       0                  0
# 8                    0.04                  0
# 9                    0.01                  0
# 10                   0.05               0.01
# 11                   0.02                  0
# 12                   0.22               0.07
# 13                   0.08               0.04
# 14                   0.07               0.01
# 15                      0                  0
# 16                   0.07               0.04
# 17                   0.07               0.04
# 18                   0.11               0.05
# 19                   0.12               0.02
# 20                    0.3               0.01
# 21                   0.04                  0
# 22                   0.01                  0
# 23                   0.05               0.01
# 24                   0.02               0.01
# 25                   0.05               0.02
# 26                    0.2               0.08
# 27                   0.13               0.06
# 28                   0.04               0.01
# 29                   0.17               0.05
# 30                   0.18               0.03
# 31                   0.27               0.13
# 32                   0.07               0.02
# 33                   0.18               0.02
# 34                   0.21               0.01
# 35                   0.24               0.04
# 36                    nan                nan

# %%
import pandas as pd
import numpy as np

# Convert columns to numeric values for calculations
numeric_cols = ['Shooting Percent_all', 'Shooting Percent_TS_True', 'Shooting Percent_TS_False', 
                'TS_True_minus_all', 'TS_True_minus_TS_False', 'all_minus_TS_False']
shooting_comparison_df[numeric_cols] = shooting_comparison_df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# Drop any rows with NaN values
shooting_comparison_df = shooting_comparison_df.dropna()

# Calculate Percentage Increase from TS_False to TS_True
shooting_comparison_df['Percent_Increase'] = ( (
    shooting_comparison_df['Shooting Percent_TS_True'] - shooting_comparison_df['Shooting Percent_TS_False']) /
    shooting_comparison_df['Shooting Percent_TS_False'].replace(0, np.nan)) * 100

# Handle cases where division by zero occurs (set to NaN)
shooting_comparison_df['Percent_Increase'] = shooting_comparison_df['Percent_Increase'].replace([np.inf, -np.inf], np.nan)

# Calculate Effect Size (Cohen's d) using a simple estimation
std_pooled = np.sqrt((shooting_comparison_df['Shooting Percent_TS_True'].std()**2 + 
                       shooting_comparison_df['Shooting Percent_TS_False'].std()**2) / 2)
shooting_comparison_df['Effect_Size'] = (
    shooting_comparison_df['Shooting Percent_TS_True'] - shooting_comparison_df['Shooting Percent_TS_False']) / std_pooled

# Round results to 3 decimal places and remove unnecessary trailing zeros
shooting_comparison_df = shooting_comparison_df.applymap(lambda x: f'{x:.3f}'.rstrip('0').rstrip('.') if isinstance(x, float) else x)

# Apply highlights to critical shot types and specific columns
def highlight_styles(row):
    styles = []
    for col in shooting_comparison_df.columns:
        if row['Chance Type'] in critical_shot_types:
            styles.append('background-color: lightyellow')
        elif col == 'Shooting Percent_TS_True':
            styles.append('background-color: #d4edda')  # light green
        elif col == 'Shooting Percent_TS_False':
            styles.append('background-color: #f8d7da')  # light red
        elif col == 'Percent_Increase':
            styles.append('background-color: #cce5ff')  # light blue
        elif col == 'Effect_Size':
            styles.append('background-color: #ffedcc')  # light orange
        else:
            styles.append('')
    return styles

styled_df = shooting_comparison_df.style.apply(highlight_styles, axis=1)

# Display the updated dataframe with metrics
print("Updated Shooting Percent Comparison with Percent Increase and Effect Size")
display(styled_df)
# Out:
# Updated Shooting Percent Comparison with Percent Increase and Effect Size
# /var/folders/mq/svx8vq1x68v157y74gk18s5m0000gn/T/ipykernel_45723/5316340.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shooting_comparison_df['Percent_Increase'] = ( (
# /var/folders/mq/svx8vq1x68v157y74gk18s5m0000gn/T/ipykernel_45723/5316340.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shooting_comparison_df['Percent_Increase'] = shooting_comparison_df['Percent_Increase'].replace([np.inf, -np.inf], np.nan)
# /var/folders/mq/svx8vq1x68v157y74gk18s5m0000gn/T/ipykernel_45723/5316340.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shooting_comparison_df['Effect_Size'] = (
# <style type="text/css">
# #T_80729_row0_col2, #T_80729_row3_col2, #T_80729_row6_col2, #T_80729_row7_col2, #T_80729_row8_col2, #T_80729_row10_col2, #T_80729_row12_col2, #T_80729_row14_col2, #T_80729_row15_col2, #T_80729_row19_col2, #T_80729_row20_col2, #T_80729_row21_col2, #T_80729_row22_col2, #T_80729_row23_col2, #T_80729_row26_col2, #T_80729_row27_col2, #T_80729_row28_col2, #T_80729_row29_col2, #T_80729_row30_col2, #T_80729_row32_col2, #T_80729_row33_col2, #T_80729_row34_col2, #T_80729_row35_col2 {
#   background-color: #d4edda;
# }
# #T_80729_row0_col3, #T_80729_row3_col3, #T_80729_row6_col3, #T_80729_row7_col3, #T_80729_row8_col3, #T_80729_row10_col3, #T_80729_row12_col3, #T_80729_row14_col3, #T_80729_row15_col3, #T_80729_row19_col3, #T_80729_row20_col3, #T_80729_row21_col3, #T_80729_row22_col3, #T_80729_row23_col3, #T_80729_row26_col3, #T_80729_row27_col3, #T_80729_row28_col3, #T_80729_row29_col3, #T_80729_row30_col3, #T_80729_row32_col3, #T_80729_row33_col3, #T_80729_row34_col3, #T_80729_row35_col3 {
#   background-color: #f8d7da;
# }
# #T_80729_row0_col7, #T_80729_row3_col7, #T_80729_row6_col7, #T_80729_row7_col7, #T_80729_row8_col7, #T_80729_row10_col7, #T_80729_row12_col7, #T_80729_row14_col7, #T_80729_row15_col7, #T_80729_row19_col7, #T_80729_row20_col7, #T_80729_row21_col7, #T_80729_row22_col7, #T_80729_row23_col7, #T_80729_row26_col7, #T_80729_row27_col7, #T_80729_row28_col7, #T_80729_row29_col7, #T_80729_row30_col7, #T_80729_row32_col7, #T_80729_row33_col7, #T_80729_row34_col7, #T_80729_row35_col7 {
#   background-color: #cce5ff;
# }
# #T_80729_row0_col8, #T_80729_row3_col8, #T_80729_row6_col8, #T_80729_row7_col8, #T_80729_row8_col8, #T_80729_row10_col8, #T_80729_row12_col8, #T_80729_row14_col8, #T_80729_row15_col8, #T_80729_row19_col8, #T_80729_row20_col8, #T_80729_row21_col8, #T_80729_row22_col8, #T_80729_row23_col8, #T_80729_row26_col8, #T_80729_row27_col8, #T_80729_row28_col8, #T_80729_row29_col8, #T_80729_row30_col8, #T_80729_row32_col8, #T_80729_row33_col8, #T_80729_row34_col8, #T_80729_row35_col8 {
#   background-color: #ffedcc;
# }
# #T_80729_row1_col0, #T_80729_row1_col1, #T_80729_row1_col2, #T_80729_row1_col3, #T_80729_row1_col4, #T_80729_row1_col5, #T_80729_row1_col6, #T_80729_row1_col7, #T_80729_row1_col8, #T_80729_row2_col0, #T_80729_row2_col1, #T_80729_row2_col2, #T_80729_row2_col3, #T_80729_row2_col4, #T_80729_row2_col5, #T_80729_row2_col6, #T_80729_row2_col7, #T_80729_row2_col8, #T_80729_row4_col0, #T_80729_row4_col1, #T_80729_row4_col2, #T_80729_row4_col3, #T_80729_row4_col4, #T_80729_row4_col5, #T_80729_row4_col6, #T_80729_row4_col7, #T_80729_row4_col8, #T_80729_row5_col0, #T_80729_row5_col1, #T_80729_row5_col2, #T_80729_row5_col3, #T_80729_row5_col4, #T_80729_row5_col5, #T_80729_row5_col6, #T_80729_row5_col7, #T_80729_row5_col8, #T_80729_row9_col0, #T_80729_row9_col1, #T_80729_row9_col2, #T_80729_row9_col3, #T_80729_row9_col4, #T_80729_row9_col5, #T_80729_row9_col6, #T_80729_row9_col7, #T_80729_row9_col8, #T_80729_row11_col0, #T_80729_row11_col1, #T_80729_row11_col2, #T_80729_row11_col3, #T_80729_row11_col4, #T_80729_row11_col5, #T_80729_row11_col6, #T_80729_row11_col7, #T_80729_row11_col8, #T_80729_row13_col0, #T_80729_row13_col1, #T_80729_row13_col2, #T_80729_row13_col3, #T_80729_row13_col4, #T_80729_row13_col5, #T_80729_row13_col6, #T_80729_row13_col7, #T_80729_row13_col8, #T_80729_row16_col0, #T_80729_row16_col1, #T_80729_row16_col2, #T_80729_row16_col3, #T_80729_row16_col4, #T_80729_row16_col5, #T_80729_row16_col6, #T_80729_row16_col7, #T_80729_row16_col8, #T_80729_row17_col0, #T_80729_row17_col1, #T_80729_row17_col2, #T_80729_row17_col3, #T_80729_row17_col4, #T_80729_row17_col5, #T_80729_row17_col6, #T_80729_row17_col7, #T_80729_row17_col8, #T_80729_row18_col0, #T_80729_row18_col1, #T_80729_row18_col2, #T_80729_row18_col3, #T_80729_row18_col4, #T_80729_row18_col5, #T_80729_row18_col6, #T_80729_row18_col7, #T_80729_row18_col8, #T_80729_row24_col0, #T_80729_row24_col1, #T_80729_row24_col2, #T_80729_row24_col3, #T_80729_row24_col4, #T_80729_row24_col5, #T_80729_row24_col6, #T_80729_row24_col7, #T_80729_row24_col8, #T_80729_row25_col0, #T_80729_row25_col1, #T_80729_row25_col2, #T_80729_row25_col3, #T_80729_row25_col4, #T_80729_row25_col5, #T_80729_row25_col6, #T_80729_row25_col7, #T_80729_row25_col8, #T_80729_row31_col0, #T_80729_row31_col1, #T_80729_row31_col2, #T_80729_row31_col3, #T_80729_row31_col4, #T_80729_row31_col5, #T_80729_row31_col6, #T_80729_row31_col7, #T_80729_row31_col8 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_80729_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chance Type</th>
#       <th class="col_heading level0 col1" >Shooting Percent_all</th>
#       <th class="col_heading level0 col2" >Shooting Percent_TS_True</th>
#       <th class="col_heading level0 col3" >Shooting Percent_TS_False</th>
#       <th class="col_heading level0 col4" >TS_True_minus_all</th>
#       <th class="col_heading level0 col5" >TS_True_minus_TS_False</th>
#       <th class="col_heading level0 col6" >all_minus_TS_False</th>
#       <th class="col_heading level0 col7" >Percent_Increase</th>
#       <th class="col_heading level0 col8" >Effect_Size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80729_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80729_row0_col0" class="data row0 col0" >Behind the Net</td>
#       <td id="T_80729_row0_col1" class="data row0 col1" >0.03</td>
#       <td id="T_80729_row0_col2" class="data row0 col2" >0.11</td>
#       <td id="T_80729_row0_col3" class="data row0 col3" >0.02</td>
#       <td id="T_80729_row0_col4" class="data row0 col4" >0.08</td>
#       <td id="T_80729_row0_col5" class="data row0 col5" >0.09</td>
#       <td id="T_80729_row0_col6" class="data row0 col6" >0.01</td>
#       <td id="T_80729_row0_col7" class="data row0 col7" >450</td>
#       <td id="T_80729_row0_col8" class="data row0 col8" >0.542</td>
#     </tr>
#     <tr>
#       <th id="T_80729_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80729_row1_col0" class="data row1 col0" >Behind the Net To Slot One Timer</td>
#       <td id="T_80729_row1_col1" class="data row1 col1" >0.22</td>
#       <td id="T_80729_row1_col2" class="data row1 col2" >0.31</td>
#       <td id="T_80729_row1_col3" class="data row1 col3" >0.19</td>
#       <td id="T_80729_row1_col4" class="data row1 col4" >0.09</td>
#       <td id="T_80729_row1_col5" class="data row1 col5" >0.12</td>
#       <td id="T_80729_row1_col6" class="data row1 col6" >0.03</td>
#       <td id="T_80729_row1_col7" class="data row1 col7" >63.158</td>
#       <td id="T_80729_row1_col8" class="data row1 col8" >0.723</td>
#     </tr>
#     <tr>
#       <th id="T_80729_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80729_row2_col0" class="data row2 col0" >Breakaway</td>
#       <td id="T_80729_row2_col1" class="data row2 col1" >0.29</td>
#       <td id="T_80729_row2_col2" class="data row2 col2" >0.3</td>
#       <td id="T_80729_row2_col3" class="data row2 col3" >0.27</td>
#       <td id="T_80729_row2_col4" class="data row2 col4" >0.01</td>
#       <td id="T_80729_row2_col5" class="data row2 col5" >0.03</td>
#       <td id="T_80729_row2_col6" class="data row2 col6" >0.02</td>
#       <td id="T_80729_row2_col7" class="data row2 col7" >11.111</td>
#       <td id="T_80729_row2_col8" class="data row2 col8" >0.181</td>
#     </tr>
#     <tr>
#       <th id="T_80729_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80729_row3_col0" class="data row3 col0" >BTN Broken Play</td>
#       <td id="T_80729_row3_col1" class="data row3 col1" >0.15</td>
#       <td id="T_80729_row3_col2" class="data row3 col2" >0.22</td>
#       <td id="T_80729_row3_col3" class="data row3 col3" >0.13</td>
#       <td id="T_80729_row3_col4" class="data row3 col4" >0.07</td>
#       <td id="T_80729_row3_col5" class="data row3 col5" >0.09</td>
#       <td id="T_80729_row3_col6" class="data row3 col6" >0.02</td>
#       <td id="T_80729_row3_col7" class="data row3 col7"

# %% [markdown]
# # How Are We Calculating It?
#
# We are using **Cohen’s d**, which measures how different two means are in terms of standard deviations.
#
# ## Formula:
# \[
# d = \frac{\text{Mean(TS_True)} - \text{Mean(TS_False)}}{\text{Pooled Standard Deviation}}
# \]
#
# ### Where:
# - **Numerator**: The difference in means (how much higher TS_True is than TS_False).
# - **Denominator**: The pooled standard deviation, which accounts for the spread of values in both TS_True and TS_False.
#
# The larger the effect size, the greater the difference between TS_True and TS_False in terms of standard deviations.
#
# ---
#
# ## Interpreting Cohen’s d
#
# | Effect Size (d) | Interpretation                  |
# |-----------------|---------------------------------|
# | 0.0 - 0.2       | Small effect (minimal impact)   |
# | 0.2 - 0.5       | Medium effect (moderate impact) |
# | 0.5 - 0.8       | Large effect (strong impact)    |
# | > 0.8           | Very large effect (significant impact) |
#
# ### For example:
# - If **Effect_Size = 0.7**, it means TS_True increases shooting percentage by **0.7 standard deviations**, which is a moderate-to-large effect.
# - If **Effect_Size = 1.5**, it suggests a **very strong impact** of TS on shooting percentage.
#
# ---
#
# ## Why Is This Useful?
#
# ### **Better Than Just Looking at Percent Increase**
# - A high percent increase (e.g., 200%) can be misleading if the baseline is very small.
# - Effect size normalizes the difference by considering how much shooting percentages vary overall.
#
# ### **Makes It Easy to Compare Different Chance Types**
# - Even if one chance type has a small absolute increase, if it has a high effect size, it means TS has a significant impact on that type of shot.

# %%
# Sort the DataFrame by Effect_Size in descending order
shooting_comparison_df = shooting_comparison_df.sort_values(by='Effect_Size', ascending=False)

# Visualize Effect Sizes as a Bar Chart with Color Categories
plt.figure(figsize=(12, 6))
plt.barh(shooting_comparison_df['Chance Type'], shooting_comparison_df['Effect_Size'], color=colors)
plt.xlabel("Effect Size (Cohen's d)")
plt.ylabel("Chance Type")
plt.title("Effect Size of Time & Space on Shooting Percentage")
plt.gca().invert_yaxis()  # Invert to show highest at top

# Highlight critical shot types by changing text color to orange and making it bold
for i, chance_type in enumerate(shooting_comparison_df['Chance Type']):
    if chance_type in critical_shot_types:
        plt.gca().get_yticklabels()[i].set_color("red")
        plt.gca().get_yticklabels()[i].set_weight("bold")

# Add a legend
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor=colors_map["Small"], label="Small Effect (<0.2)"),
    Patch(facecolor=colors_map["Medium"], label="Medium Effect (0.2 - 0.5)"),
    Patch(facecolor=colors_map["Large"], label="Large Effect (0.5 - 0.8)"),
    Patch(facecolor=colors_map["Very Large"], label="Very Large Effect (>0.8)")
]
plt.legend(handles=legend_elements, loc="lower right")
plt.show()

# %% [markdown]
# # Analysis of Time and Space (TS) Impact on Shooting Percentage
#
# This is a fantastic dataset, and it’s clear you’re diving deep into the impact of **Time and Space (TS)** on shooting percentages in hockey. Let’s break this down and interpret the results, especially focusing on the **Effect Size (Cohen's d)** and how it relates to the **danger levels** of the chances (High, Mid, Low).
#
# ---
#
# ## **1. Key Observations from the Data**
#
# - **Effect Size (Cohen's d)**:
#   - This measures the magnitude of the difference in shooting percentage between shots with **Time and Space (TS_True)** and shots without **Time and Space (TS_False)**.
#   - A higher Cohen's d indicates a stronger impact of TS on shooting percentage.
#
# - **Percent Increase**:
#   - This shows the relative improvement in shooting percentage when TS is present compared to when it’s absent.
#   - However, as you noted earlier, percent increase can be misleading if the baseline (TS_False) is very low. This is why **Effect Size** is a more reliable metric.
#
# - **Danger Levels**:
#   - **High Danger**: 20% or greater chance to score.
#   - **Mid Danger**: 9-19% chance to score.
#   - **Low Danger**: 8% or lower chance to score.
#
# ---
#
# ## **2. General Trends in the Data**
#
# - **High Danger Chances**:
#   - These already have a high baseline shooting percentage, so the impact of TS might be less pronounced in terms of **percent increase** but still significant in terms of **effect size**.
#   - Example: **Slot Line Double** has a high baseline shooting percentage (TS_False = 0.41), but TS_True increases it to 0.68, with a large effect size (d = 1.642).
#
# - **Mid Danger Chances**:
#   - These show a mix of moderate to large effect sizes, indicating that TS has a meaningful impact on shooting percentage.
#   - Example: **Mid % Broken Play** has a moderate baseline (TS_False = 0.21), but TS_True increases it to 0.33, with a large effect size (d = 0.73).
#
# - **Low Danger Chances**:
#   - These often have a low baseline shooting percentage, so even small absolute increases can result in large **percent increases** and **effect sizes**.
#   - Example: **Strong Mid % Rebound** has a low baseline (TS_False = 0.07), but TS_True increases it to 0.28, with a very large effect size (d = 1.277).
#
# ---
#
# ## **3. Highlighting Key Findings**
#
# ### **High Effect Sizes (d > 0.8)**:
# These indicate a **very strong impact** of TS on shooting percentage. Examples include:
# - **Net Broken Play**: d = 1.825 (baseline TS_False = 0.12, TS_True = 0.42)
# - **Slot Line Double**: d = 1.642 (baseline TS_False = 0.41, TS_True = 0.68)
# - **Strong Mid % Rebound**: d = 1.277 (baseline TS_False = 0.07, TS_True = 0.28)
# - **Weak Mid % Rebound**: d = 1.46 (baseline TS_False = 0.38, TS_True = 0.62)
#
# These are situations where **Time and Space** dramatically improve shooting percentage, often turning low- or mid-danger chances into high-danger opportunities.
#
# ### **Moderate Effect Sizes (0.5 < d < 0.8)**:
# These indicate a **moderate to strong impact** of TS. Examples include:
# - **Behind the Net**: d = 0.547 (baseline TS_False = 0.02, TS_True = 0.11)
# - **CS Broken Play**: d = 0.73 (baseline TS_False = 0.09, TS_True = 0.21)
# - **Screened One Timer**: d = 0.791 (baseline TS_False = 0.26, TS_True = 0.39)
#
# These are situations where TS still has a meaningful impact, but the effect isn’t as dramatic as in the high-effect-size cases.
#
# ### **Small Effect Sizes (d < 0.5)**:
# These indicate a **minimal to moderate impact** of TS. Examples include:
# - **Breakaway**: d = 0.182 (bas

# %%
# Reorder the columns
column_order = [
    'Chance Type', 
    'Shooting Percent_all', 
    'Historical % (All)', 
    'Shooting Percent_TS_True', 
    'Historical % (TS_True)', 
    'Shooting Percent_TS_False', 
    'Historical % (TS_False)', 
    'Effect_Size_Category'
]
shooting_historical_df = shooting_historical_df[column_order]

# Remove unnecessary trailing zeros from numeric columns
def remove_trailing_zeros(value):
    if isinstance(value, (float, np.floating)):
        return f'{value:.6f}'.rstrip('0').rstrip('.') if '.' in f'{value:.6f}' else f'{value:.6f}'
    elif isinstance(value, str):
        return value.rstrip('0').rstrip('.') if '.' in value else value
    return value

# Apply the function to clean up trailing zeros
shooting_historical_df = shooting_historical_df.applymap(remove_trailing_zeros)

# Apply highlights to critical shot types and specific columns
def highlight_styles(row):
    styles = []
    for col in shooting_historical_df.columns:
        if row['Chance Type'] in critical_shot_types:
            styles.append('background-color: lightyellow')
        elif col == 'Shooting Percent_TS_True':
            styles.append('background-color: #d4edda')  # light green
        elif col == 'Shooting Percent_TS_False':
            styles.append('background-color: #f8d7da')  # light red
        elif col == 'Historical % (TS_True)':
            styles.append('background-color: #d4edda')  # light green
        elif col == 'Historical % (TS_False)':
            styles.append('background-color: #f8d7da')  # light red
        else:
            styles.append('')
    return styles

# Apply the styling to the new DataFrame
styled_historical_df = shooting_historical_df.style.apply(highlight_styles, axis=1)

# Display the updated dataframe with metrics
print("Updated Shooting Percent Comparison with Historical Percentages")
display(styled_historical_df)
# Out:
# Updated Shooting Percent Comparison with Historical Percentages
# <style type="text/css">
# #T_8fe9b_row0_col3, #T_8fe9b_row0_col4, #T_8fe9b_row2_col3, #T_8fe9b_row2_col4, #T_8fe9b_row3_col3, #T_8fe9b_row3_col4, #T_8fe9b_row4_col3, #T_8fe9b_row4_col4, #T_8fe9b_row5_col3, #T_8fe9b_row5_col4, #T_8fe9b_row6_col3, #T_8fe9b_row6_col4, #T_8fe9b_row7_col3, #T_8fe9b_row7_col4, #T_8fe9b_row8_col3, #T_8fe9b_row8_col4, #T_8fe9b_row9_col3, #T_8fe9b_row9_col4, #T_8fe9b_row10_col3, #T_8fe9b_row10_col4, #T_8fe9b_row15_col3, #T_8fe9b_row15_col4, #T_8fe9b_row16_col3, #T_8fe9b_row16_col4, #T_8fe9b_row20_col3, #T_8fe9b_row20_col4, #T_8fe9b_row21_col3, #T_8fe9b_row21_col4, #T_8fe9b_row22_col3, #T_8fe9b_row22_col4, #T_8fe9b_row23_col3, #T_8fe9b_row23_col4, #T_8fe9b_row25_col3, #T_8fe9b_row25_col4, #T_8fe9b_row26_col3, #T_8fe9b_row26_col4, #T_8fe9b_row27_col3, #T_8fe9b_row27_col4, #T_8fe9b_row30_col3, #T_8fe9b_row30_col4, #T_8fe9b_row32_col3, #T_8fe9b_row32_col4, #T_8fe9b_row34_col3, #T_8fe9b_row34_col4, #T_8fe9b_row35_col3, #T_8fe9b_row35_col4 {
#   background-color: #d4edda;
# }
# #T_8fe9b_row0_col5, #T_8fe9b_row0_col6, #T_8fe9b_row2_col5, #T_8fe9b_row2_col6, #T_8fe9b_row3_col5, #T_8fe9b_row3_col6, #T_8fe9b_row4_col5, #T_8fe9b_row4_col6, #T_8fe9b_row5_col5, #T_8fe9b_row5_col6, #T_8fe9b_row6_col5, #T_8fe9b_row6_col6, #T_8fe9b_row7_col5, #T_8fe9b_row7_col6, #T_8fe9b_row8_col5, #T_8fe9b_row8_col6, #T_8fe9b_row9_col5, #T_8fe9b_row9_col6, #T_8fe9b_row10_col5, #T_8fe9b_row10_col6, #T_8fe9b_row15_col5, #T_8fe9b_row15_col6, #T_8fe9b_row16_col5, #T_8fe9b_row16_col6, #T_8fe9b_row20_col5, #T_8fe9b_row20_col6, #T_8fe9b_row21_col5, #T_8fe9b_row21_col6, #T_8fe9b_row22_col5, #T_8fe9b_row22_col6, #T_8fe9b_row23_col5, #T_8fe9b_row23_col6, #T_8fe9b_row25_col5, #T_8fe9b_row25_col6, #T_8fe9b_row26_col5, #T_8fe9b_row26_col6, #T_8fe9b_row27_col5, #T_8fe9b_row27_col6, #T_8fe9b_row30_col5, #T_8fe9b_row30_col6, #T_8fe9b_row32_col5, #T_8fe9b_row32_col6, #T_8fe9b_row34_col5, #T_8fe9b_row34_col6, #T_8fe9b_row35_col5, #T_8fe9b_row35_col6 {
#   background-color: #f8d7da;
# }
# #T_8fe9b_row1_col0, #T_8fe9b_row1_col1, #T_8fe9b_row1_col2, #T_8fe9b_row1_col3, #T_8fe9b_row1_col4, #T_8fe9b_row1_col5, #T_8fe9b_row1_col6, #T_8fe9b_row1_col7, #T_8fe9b_row11_col0, #T_8fe9b_row11_col1, #T_8fe9b_row11_col2, #T_8fe9b_row11_col3, #T_8fe9b_row11_col4, #T_8fe9b_row11_col5, #T_8fe9b_row11_col6, #T_8fe9b_row11_col7, #T_8fe9b_row12_col0, #T_8fe9b_row12_col1, #T_8fe9b_row12_col2, #T_8fe9b_row12_col3, #T_8fe9b_row12_col4, #T_8fe9b_row12_col5, #T_8fe9b_row12_col6, #T_8fe9b_row12_col7, #T_8fe9b_row13_col0, #T_8fe9b_row13_col1, #T_8fe9b_row13_col2, #T_8fe9b_row13_col3, #T_8fe9b_row13_col4, #T_8fe9b_row13_col5, #T_8fe9b_row13_col6, #T_8fe9b_row13_col7, #T_8fe9b_row14_col0, #T_8fe9b_row14_col1, #T_8fe9b_row14_col2, #T_8fe9b_row14_col3, #T_8fe9b_row14_col4, #T_8fe9b_row14_col5, #T_8fe9b_row14_col6, #T_8fe9b_row14_col7, #T_8fe9b_row17_col0, #T_8fe9b_row17_col1, #T_8fe9b_row17_col2, #T_8fe9b_row17_col3, #T_8fe9b_row17_col4, #T_8fe9b_row17_col5, #T_8fe9b_row17_col6, #T_8fe9b_row17_col7, #T_8fe9b_row18_col0, #T_8fe9b_row18_col1, #T_8fe9b_row18_col2, #T_8fe9b_row18_col3, #T_8fe9b_row18_col4, #T_8fe9b_row18_col5, #T_8fe9b_row18_col6, #T_8fe9b_row18_col7, #T_8fe9b_row19_col0, #T_8fe9b_row19_col1, #T_8fe9b_row19_col2, #T_8fe9b_row19_col3, #T_8fe9b_row19_col4, #T_8fe9b_row19_col5, #T_8fe9b_row19_col6, #T_8fe9b_row19_col7, #T_8fe9b_row24_col0, #T_8fe9b_row24_col1, #T_8fe9b_row24_col2, #T_8fe9b_row24_col3, #T_8fe9b_row24_col4, #T_8fe9b_row24_col5, #T_8fe9b_row24_col6, #T_8fe9b_row24_col7, #T_8fe9b_row28_col0, #T_8fe9b_row28_col1, #T_8fe9b_row28_col2, #T_8fe9b_row28_col3, #T_8fe9b_row28_col4, #T_8fe9b_row28_col5, #T_8fe9b_row28_col6, #T_8fe9b_row28_col7, #T_8fe9b_row29_col0, #T_8fe9b_row29_col1, #T_8fe9b_row29_col2, #T_8fe9b_row29_col3, #T_8fe9b_row29_col4, #T_8fe9b_row29_col5, #T_8fe9b_row29_col6, #T_8fe9b_row29_col7, #T_8fe9b_row31_col0, #T_8fe9b_row31_col1, #T_8fe9b_row31_col2, #T_8fe9b_row31_col3, #T_8fe9b_row31_col4, #T_8fe9b_row31_col5, #T_8fe9b_row31_col6, #T_8fe9b_row31_col7, #T_8fe9b_row33_col0, #T_8fe9b_row33_col1, #T_8fe9b_row33_col2, #T_8fe9b_row33_col3, #T_8fe9b_row33_col4, #T_8fe9b_row33_col5, #T_8fe9b_row33_col6, #T_8fe9b_row33_col7 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_8fe9b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chance Type</th>
#       <th class="col_heading level0 col1" >Shooting Percent_all</th>
#       <th class="col_heading level0 col2" >Historical % (All)</th>
#       <th class="col_heading level0 col3" >Shooting Percent_TS_True</th>
#       <th class="col_heading level0 col4" >Historical % (TS_True)</th>
#       <th class="col_heading level0 col5" >Shooting Percent_TS_False</th>
#       <th class="col_heading level0 col6" >Historical % (TS_False)</th>
#       <th class="col_heading level0 col7" >Effect_Size_Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fe9b_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_8fe9b_row0_col0" class="data row0 col0" >Net Broken Play</td>
#       <td id="T_8fe9b_row0_col1" class="data row0 col1" >0.13</td>
#       <td id="T_8fe9b_row0_col2" class="data row0 col2" >0.26</td>
#       <td id="T_8fe9b_row0_col3" class="data row0 col3" >0.42</td>
#       <td id="T_8fe9b_row0_col4" class="data row0 col4" >0.26</td>
#       <td id="T_8fe9b_row0_col5" class="data row0 col5" >0.12</td>
#       <td id="T_8fe9b_row0_col6" class="data row0 col6" >0.12</td>
#       <td id="T_8fe9b_row0_col7" class="data row0 col7" >Very Large</td>
#     </tr>
#     <tr>
#       <th id="T_8fe9b_level0_row1" class="row_heading level0 row1" >31</th>
#       <td id="T_8fe9b_row1_col0" class="data row1 col0" >Slot Line Double</td>
#       <td id="T_8fe9b_row1_col1" class="data row1 col1" >0.54</td>
#       <td id="T_8fe9b_row1_col2" class="data row1 col2" >0.2</td>
#       <td id="T_8fe9b_row1_col3" class="data row1 col3" >0.68</td>
#       <td id="T_8fe9b_row1_col4" class="data row1 col4" >0.2</td>
#       <td id="T_8fe9b_row1_col5" class="data row1 col5" >0.41</td>
#       <td id="T_8fe9b_row1_col6" class="data row1 col6" >0.49</td>
#       <td id="T_8fe9b_row1_col7" class="data row1 col7" >Very Large</td>
#     </tr>
#     <tr>
#       <th id="T_8fe9b_level0_row2" class="row_heading level0 row2" >35</th>
#       <td id="T_8fe9b_row2_col0" class="data row2 col0" >Weak Mid % Rebound</td>
#       <td id="T_8fe9b_row2_col1" class="data row2 col1" >0.42</td>
#       <td id="T_8fe9b_row2_col2" class="data row2 col2" >0.11</td>
#       <td id="T_8fe9b_row2_col3" class="data row2 col3" >0.62</td>
#       <td id="T_8fe9b_row2_col4" class="data row2 col4" >0.09</td>
#       <td id="T_8fe9b_row2_col5" class="data row2 col5" >0.38</td>
#       <td id="T_8fe9b_row2_col6" class="data row2 col6" >0.09</td>
#       <td id="T_8fe9b_row2_col7" class="data row2 col7" >Very Large</td>
#     </tr>
#     <tr>
#       <th id="T_8fe9b_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_8fe9b_row3_col0" class="data row3 col0" >Goalie Error</td>
#       <td id="T_8fe9b_row3_col1" class="data row3 col1" >0.64</td>
#       <td id="T_8fe9b_row3_col2" class="data row3 col2" >0.03</td>
#       <td id="T_8fe9b_row3_col3" class="data row3 col3" >0.79</td>
#       <td id="T_8fe9b_row3_col4" class="data row3 col4" >0.03</td>
#       <td id="T_8fe9b_row3_col5" class="data row3 col5" >0.57</td>
#       <td id="T_8fe9b_row3_col6" class="data row3 col6" >0.01</td>
#       <td id="T_8fe9b_row3_col7" class="data row3 col7" >Very Large</td>
#     </tr>
#     <tr>
#       <th id="T_8fe9b_level0_row4" class="row_heading level0 row4" >34</th>
#       <td id="T_8fe9b_row4_col0" class="data row4 col0" >Strong Mid % Rebound</td>
#       <td id="T_8fe9b_row4_col1" class="data row4 col1" >0.08</td>
#       <td id="T_8fe9b_row4_col2" class="data row4 col2" >0.04</td>
#       <td id="T_8fe9b_row4_col3" class="data row4 col3" >0.28</td>
#       <td id="T_8fe9b_row4_col4" class="data row4 col4" >0.11</td>
#       <td id="T_8fe9b_row4_col5" class="data row4 col5" >0.07</td>
#       <td id="T_8fe9b_row4_col

# %%
import numpy as np
import pandas as pd

# Ensure numeric columns are treated as floats
numeric_cols = ['Shooting Percent_all', 'Historical % (All)']
shooting_historical_df[numeric_cols] = shooting_historical_df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# Calculate Cohen's d for each row
std_pooled = np.sqrt((shooting_historical_df['Shooting Percent_all'].std()**2 + 
                       shooting_historical_df['Historical % (All)'].std()**2) / 2)
shooting_historical_df['Cohen_d_All'] = (
    shooting_historical_df['Shooting Percent_all'] - shooting_historical_df['Historical % (All)']) / std_pooled

# Function to categorize Cohen's d
def categorize_cohens_d(value):
    abs_value = abs(value)
    if abs_value < 0.2:
        return "Small"
    elif abs_value < 0.5:
        return "Medium"
    elif abs_value < 0.8:
        return "Large"
    else:
        return "Very Large"

# Apply categorization to Cohen's d
shooting_historical_df['Cohen_d_All_Category'] = shooting_historical_df['Cohen_d_All'].apply(categorize_cohens_d)

# Remove unnecessary trailing zeros from numeric columns
def remove_trailing_zeros(value):
    if isinstance(value, (float, np.floating)):
        return f'{value:.6f}'.rstrip('0').rstrip('.') if '.' in f'{value:.6f}' else f'{value:.6f}'
    return value

# Apply cleanup to all numeric columns
shooting_historical_df = shooting_historical_df.applymap(remove_trailing_zeros)

# Select relevant columns for the 'all' dataframe
df_all = shooting_historical_df[['Chance Type', 'Shooting Percent_all', 'Historical % (All)', 'Cohen_d_All', 'Cohen_d_All_Category']]

# Display the dataframe
display(df_all)
# Out:
#                          Chance Type Shooting Percent_all Historical % (All)  \
# 20                   Net Broken Play                 0.13               0.26
# 31                  Slot Line Double                 0.54                0.2
# 35                Weak Mid % Rebound                 0.42               0.11
# 12                      Goalie Error                 0.64               0.03
# 34              Strong Mid % Rebound                 0.08               0.04
# 26                Passed Off Rebound                 0.43               0.23
# 33             Strong High % Rebound                 0.11               0.12
# 30                   Slot Line Carry                 0.17                0.3
# 29                  Slot Area Screen                 0.29               0.23
# 27                Screened One Timer                 0.32               0.55
# 19                 Mid % Broken Play                 0.23               0.36
# 1   Behind the Net To Slot One Timer                 0.22                0.2
# 4                     CS Broken Play                 0.12                0.1
# 18                Low Slot Line Pass                 0.34               0.18
# 5               CS Odd Man Rush Slot                  0.2               0.22
# 0                     Behind the Net                 0.03               0.02
# 3                    BTN Broken Play                 0.15               0.13
# 13                Half-Ice Breakaway                 0.13               0.01
# 17                    Layered Screen                 0.15                0.2
# 16               High Slot Line Pass                 0.16               0.01
# 32                    Slot One Timer                 0.11               0.49
# 14                High % Broken Play                 0.38               0.15
# 10                 Deflection In Air                 0.14               0.15
# 23            One Timer / Deflection                  0.1               0.04
# 25                 Partial Breakaway                 0.26               0.03
# 21                          Net Play                 0.02               0.12
# 8                       CS Slot Area                 0.03               0.04
# 28               Screened/Deflection                 0.19               0.34
# 2                          Breakaway                 0.29               0.32
# 24       One Timer Outside Slot Area                 0.04               0.25
# 6               CS Outside Slot Area                 0.02               0.01
# 11                 Deflection On Ice                 0.04               0.15
# 22                  Offensive Screen                 0.04               0.03
# 9                   Defensive Screen                 0.08                0.1
# 15                    High One Timer                 0.01               0.39
# 7                       CS Perimeter                    0                  0
#
#    Cohen_d_All Cohen_d_All_Category
# 20   -0.878823           Very Large
# 31    2.298461           Very Large
# 35    2.095656           Very Large
# 12    4.123709           Very Large
# 34    0.270407               Medium
# 26    1.352036           Very Large
# 33   -0.067602                Small
# 30   -0.878823           Very Large
# 29    0.405611               Medium
# 27   -1.554841           Very Large
# 19   -0.878823           Very Large
# 1     0.135204                Small
# 4     0.135204                Small
# 18    1.081629           Very Large
# 5    -0.135204                Small
# 0     0.067602                Small
# 3     0.135204                Small
# 13    0.811222           Very Large
# 17   -0.338009               Medium
# 16    1.014027           Very Large
# 32   -2.568868           Very Large
# 14    1.554841           Very Large
# 10   -0.067602                Small
# 23    0.405611               Medium
# 25    1.554841           Very Large
# 21   -0.676018                Large
# 8    -0.067602                Small
# 28   -1.014027           Very Large
# 2    -0.202805               Medium
# 24   -1.419638           Very Large
# 6     0.067602                Small
# 11    -0.74362                Large
# 22    0.067602                Small
# 9    -0.135204                Small
# 15   -2.568868           Very Large
# 7            0                Small

# %%
import numpy as np

# Ensure numeric columns are treated as floats
numeric_cols = [
    'Shooting Percent_all', 
    'Historical % (All)', 
    'Shooting Percent_TS_True', 
    'Historical % (TS_True)', 
    'Shooting Percent_TS_False', 
    'Historical % (TS_False)'
]
shooting_historical_df[numeric_cols] = shooting_historical_df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# Function to calculate Cohen's d
def cohens_d(current, historical):
    pooled_std = np.sqrt((current.std()**2 + historical.std()**2) / 2)
    return (current.mean() - historical.mean()) / pooled_std

# Calculate Cohen's d for each comparison
shooting_historical_df['Cohen_d_All'] = cohens_d(
    shooting_historical_df['Shooting Percent_all'], 
    shooting_historical_df['Historical % (All)']
)
shooting_historical_df['Cohen_d_TS_True'] = cohens_d(
    shooting_historical_df['Shooting Percent_TS_True'], 
    shooting_historical_df['Historical % (TS_True)']
)
shooting_historical_df['Cohen_d_TS_False'] = cohens_d(
    shooting_historical_df['Shooting Percent_TS_False'], 
    shooting_historical_df['Historical % (TS_False)']
)

# Function to categorize Cohen's d
def categorize_cohens_d(value):
    if abs(value) < 0.2:
        return "Small"
    elif abs(value) < 0.5:
        return "Medium"
    elif abs(value) < 0.8:
        return "Large"
    else:
        return "Very Large"

# Apply categorization to Cohen's d columns
shooting_historical_df['Cohen_d_All_Category'] = shooting_historical_df['Cohen_d_All'].apply(categorize_cohens_d)
shooting_historical_df['Cohen_d_TS_True_Category'] = shooting_historical_df['Cohen_d_TS_True'].apply(categorize_cohens_d)
shooting_historical_df['Cohen_d_TS_False_Category'] = shooting_historical_df['Cohen_d_TS_False'].apply(categorize_cohens_d)

# Remove the Effect_Size_Category column
shooting_historical_df = shooting_historical_df.drop(columns=['Effect_Size_Category'])

# Remove unnecessary trailing zeros from numeric columns
def remove_trailing_zeros(value):
    if isinstance(value, (float, np.floating)):
        return f'{value:.6f}'.rstrip('0').rstrip('.') if '.' in f'{value:.6f}' else f'{value:.6f}'
    elif isinstance(value, str):
        return value.rstrip('0').rstrip('.') if '.' in value else value
    return value

# Apply the function to clean up trailing zeros
shooting_historical_df = shooting_historical_df.applymap(remove_trailing_zeros)

# Split into three DataFrames
df_all = shooting_historical_df[['Chance Type', 'Shooting Percent_all', 'Historical % (All)', 'Cohen_d_All', 'Cohen_d_All_Category']]
df_ts_true = shooting_historical_df[['Chance Type', 'Shooting Percent_TS_True', 'Historical % (TS_True)', 'Cohen_d_TS_True', 'Cohen_d_TS_True_Category']]
df_ts_false = shooting_historical_df[['Chance Type', 'Shooting Percent_TS_False', 'Historical % (TS_False)', 'Cohen_d_TS_False', 'Cohen_d_TS_False_Category']]

# Apply highlights to critical shot types and specific columns
def highlight_styles(row):
    styles = []
    for col in row.index:
        if row['Chance Type'] in critical_shot_types:
            styles.append('background-color: lightyellow')
        elif col == 'Shooting Percent_TS_True':
            styles.append('background-color: #d4edda')  # light green
        elif col == 'Shooting Percent_TS_False':
            styles.append('background-color: #f8d7da')  # light red
        elif col == 'Historical % (TS_True)':
            styles.append('background-color: #d4edda')  # light green
        elif col == 'Historical % (TS_False)':
            styles.append('background-color: #f8d7da')  # light red
        else:
            styles.append('')
    return styles

# Apply the styling to each DataFrame
styled_df_all = df_all.style.apply(highlight_styles, axis=1)
styled_df_ts_true = df_ts_true.style.apply(highlight_styles, axis=1)
styled_df_ts_false = df_ts_false.style.apply(highlight_styles, axis=1)

# Display the updated dataframes with metrics
print("Shooting Percent Comparison: All Shots")
display(styled_df_all)

print("\nShooting Percent Comparison: TS_True Shots")
display(styled_df_ts_true)

print("\nShooting Percent Comparison: TS_False Shots")
display(styled_df_ts_false)
# Out:
# Shooting Percent Comparison: All Shots
# <style type="text/css">
# #T_64b1b_row1_col0, #T_64b1b_row1_col1, #T_64b1b_row1_col2, #T_64b1b_row1_col3, #T_64b1b_row1_col4, #T_64b1b_row11_col0, #T_64b1b_row11_col1, #T_64b1b_row11_col2, #T_64b1b_row11_col3, #T_64b1b_row11_col4, #T_64b1b_row12_col0, #T_64b1b_row12_col1, #T_64b1b_row12_col2, #T_64b1b_row12_col3, #T_64b1b_row12_col4, #T_64b1b_row13_col0, #T_64b1b_row13_col1, #T_64b1b_row13_col2, #T_64b1b_row13_col3, #T_64b1b_row13_col4, #T_64b1b_row14_col0, #T_64b1b_row14_col1, #T_64b1b_row14_col2, #T_64b1b_row14_col3, #T_64b1b_row14_col4, #T_64b1b_row17_col0, #T_64b1b_row17_col1, #T_64b1b_row17_col2, #T_64b1b_row17_col3, #T_64b1b_row17_col4, #T_64b1b_row18_col0, #T_64b1b_row18_col1, #T_64b1b_row18_col2, #T_64b1b_row18_col3, #T_64b1b_row18_col4, #T_64b1b_row19_col0, #T_64b1b_row19_col1, #T_64b1b_row19_col2, #T_64b1b_row19_col3, #T_64b1b_row19_col4, #T_64b1b_row24_col0, #T_64b1b_row24_col1, #T_64b1b_row24_col2, #T_64b1b_row24_col3, #T_64b1b_row24_col4, #T_64b1b_row28_col0, #T_64b1b_row28_col1, #T_64b1b_row28_col2, #T_64b1b_row28_col3, #T_64b1b_row28_col4, #T_64b1b_row29_col0, #T_64b1b_row29_col1, #T_64b1b_row29_col2, #T_64b1b_row29_col3, #T_64b1b_row29_col4, #T_64b1b_row31_col0, #T_64b1b_row31_col1, #T_64b1b_row31_col2, #T_64b1b_row31_col3, #T_64b1b_row31_col4, #T_64b1b_row33_col0, #T_64b1b_row33_col1, #T_64b1b_row33_col2, #T_64b1b_row33_col3, #T_64b1b_row33_col4 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_64b1b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chance Type</th>
#       <th class="col_heading level0 col1" >Shooting Percent_all</th>
#       <th class="col_heading level0 col2" >Historical % (All)</th>
#       <th class="col_heading level0 col3" >Cohen_d_All</th>
#       <th class="col_heading level0 col4" >Cohen_d_All_Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64b1b_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_64b1b_row0_col0" class="data row0 col0" >Net Broken Play</td>
#       <td id="T_64b1b_row0_col1" class="data row0 col1" >0.13</td>
#       <td id="T_64b1b_row0_col2" class="data row0 col2" >0.26</td>
#       <td id="T_64b1b_row0_col3" class="data row0 col3" >0.093891</td>
#       <td id="T_64b1b_row0_col4" class="data row0 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row1" class="row_heading level0 row1" >31</th>
#       <td id="T_64b1b_row1_col0" class="data row1 col0" >Slot Line Double</td>
#       <td id="T_64b1b_row1_col1" class="data row1 col1" >0.54</td>
#       <td id="T_64b1b_row1_col2" class="data row1 col2" >0.2</td>
#       <td id="T_64b1b_row1_col3" class="data row1 col3" >0.093891</td>
#       <td id="T_64b1b_row1_col4" class="data row1 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row2" class="row_heading level0 row2" >35</th>
#       <td id="T_64b1b_row2_col0" class="data row2 col0" >Weak Mid % Rebound</td>
#       <td id="T_64b1b_row2_col1" class="data row2 col1" >0.42</td>
#       <td id="T_64b1b_row2_col2" class="data row2 col2" >0.11</td>
#       <td id="T_64b1b_row2_col3" class="data row2 col3" >0.093891</td>
#       <td id="T_64b1b_row2_col4" class="data row2 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_64b1b_row3_col0" class="data row3 col0" >Goalie Error</td>
#       <td id="T_64b1b_row3_col1" class="data row3 col1" >0.64</td>
#       <td id="T_64b1b_row3_col2" class="data row3 col2" >0.03</td>
#       <td id="T_64b1b_row3_col3" class="data row3 col3" >0.093891</td>
#       <td id="T_64b1b_row3_col4" class="data row3 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row4" class="row_heading level0 row4" >34</th>
#       <td id="T_64b1b_row4_col0" class="data row4 col0" >Strong Mid % Rebound</td>
#       <td id="T_64b1b_row4_col1" class="data row4 col1" >0.08</td>
#       <td id="T_64b1b_row4_col2" class="data row4 col2" >0.04</td>
#       <td id="T_64b1b_row4_col3" class="data row4 col3" >0.093891</td>
#       <td id="T_64b1b_row4_col4" class="data row4 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row5" class="row_heading level0 row5" >26</th>
#       <td id="T_64b1b_row5_col0" class="data row5 col0" >Passed Off Rebound</td>
#       <td id="T_64b1b_row5_col1" class="data row5 col1" >0.43</td>
#       <td id="T_64b1b_row5_col2" class="data row5 col2" >0.23</td>
#       <td id="T_64b1b_row5_col3" class="data row5 col3" >0.093891</td>
#       <td id="T_64b1b_row5_col4" class="data row5 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row6" class="row_heading level0 row6" >33</th>
#       <td id="T_64b1b_row6_col0" class="data row6 col0" >Strong High % Rebound</td>
#       <td id="T_64b1b_row6_col1" class="data row6 col1" >0.11</td>
#       <td id="T_64b1b_row6_col2" class="data row6 col2" >0.12</td>
#       <td id="T_64b1b_row6_col3" class="data row6 col3" >0.093891</td>
#       <td id="T_64b1b_row6_col4" class="data row6 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row7" class="row_heading level0 row7" >30</th>
#       <td id="T_64b1b_row7_col0" class="data row7 col0" >Slot Line Carry</td>
#       <td id="T_64b1b_row7_col1" class="data row7 col1" >0.17</td>
#       <td id="T_64b1b_row7_col2" class="data row7 col2" >0.3</td>
#       <td id="T_64b1b_row7_col3" class="data row7 col3" >0.093891</td>
#       <td id="T_64b1b_row7_col4" class="data row7 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row8" class="row_heading level0 row8" >29</th>
#       <td id="T_64b1b_row8_col0" class="data row8 col0" >Slot Area Screen</td>
#       <td id="T_64b1b_row8_col1" class="data row8 col1" >0.29</td>
#       <td id="T_64b1b_row8_col2" class="data row8 col2" >0.23</td>
#       <td id="T_64b1b_row8_col3" class="data row8 col3" >0.093891</td>
#       <td id="T_64b1b_row8_col4" class="data row8 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row9" class="row_heading level0 row9" >27</th>
#       <td id="T_64b1b_row9_col0" class="data row9 col0" >Screened One Timer</td>
#       <td id="T_64b1b_row9_col1" class="data row9 col1" >0.32</td>
#       <td id="T_64b1b_row9_col2" class="data row9 col2" >0.55</td>
#       <td id="T_64b1b_row9_col3" class="data row9 col3" >0.093891</td>
#       <td id="T_64b1b_row9_col4" class="data row9 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row10" class="row_heading level0 row10" >19</th>
#       <td id="T_64b1b_row10_col0" class="data row10 col0" >Mid % Broken Play</td>
#       <td id="T_64b1b_row10_col1" class="data row10 col1" >0.23</td>
#       <td id="T_64b1b_row10_col2" class="data row10 col2" >0.36</td>
#       <td id="T_64b1b_row10_col3" class="data row10 col3" >0.093891</td>
#       <td id="T_64b1b_row10_col4" class="data row10 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row11" class="row_heading level0 row11" >1</th>
#       <td id="T_64b1b_row11_col0" class="data row11 col0" >Behind the Net To Slot One Timer</td>
#       <td id="T_64b1b_row11_col1" class="data row11 col1" >0.22</td>
#       <td id="T_64b1b_row11_col2" class="data row11 col2" >0.2</td>
#       <td id="T_64b1b_row11_col3" class="data row11 col3" >0.093891</td>
#       <td id="T_64b1b_row11_col4" class="data row11 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row12" class="row_heading level0 row12" >4</th>
#       <td id="T_64b1b_row12_col0" class="data row12 col0" >CS Broken Play</td>
#       <td id="T_64b1b_row12_col1" class="data row12 col1" >0.12</td>
#       <td id="T_64b1b_row12_col2" class="data row12 col2" >0.1</td>
#       <td id="T_64b1b_row12_col3" class="data row12 col3" >0.093891</td>
#       <td id="T_64b1b_row12_col4" class="data row12 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_64b1b_level0_row13" class="row_heading level0 row13" >18</th>
#       <td id="T_64b1b_row13_col0" class="data row13 col0" >Low Slot Line Pass</td>
#       <td id="T_64b1b_row13_col1" class="data row13 col1" >0.34</td>
#       <td id="T_64b1b_row1
# Shooting Percent Comparison: TS_True Shots
# <style type="text/css">
# #T_d3762_row0_col1, #T_d3762_row0_col2, #T_d3762_row2_col1, #T_d3762_row2_col2, #T_d3762_row3_col1, #T_d3762_row3_col2, #T_d3762_row4_col1, #T_d3762_row4_col2, #T_d3762_row5_col1, #T_d3762_row5_col2, #T_d3762_row6_col1, #T_d3762_row6_col2, #T_d3762_row7_col1, #T_d3762_row7_col2, #T_d3762_row8_col1, #T_d3762_row8_col2, #T_d3762_row9_col1, #T_d3762_row9_col2, #T_d3762_row10_col1, #T_d3762_row10_col2, #T_d3762_row15_col1, #T_d3762_row15_col2, #T_d3762_row16_col1, #T_d3762_row16_col2, #T_d3762_row20_col1, #T_d3762_row20_col2, #T_d3762_row21_col1, #T_d3762_row21_col2, #T_d3762_row22_col1, #T_d3762_row22_col2, #T_d3762_row23_col1, #T_d3762_row23_col2, #T_d3762_row25_col1, #T_d3762_row25_col2, #T_d3762_row26_col1, #T_d3762_row26_col2, #T_d3762_row27_col1, #T_d3762_row27_col2, #T_d3762_row30_col1, #T_d3762_row30_col2, #T_d3762_row32_col1, #T_d3762_row32_col2, #T_d3762_row34_col1, #T_d3762_row34_col2, #T_d3762_row35_col1, #T_d3762_row35_col2 {
#   background-color: #d4edda;
# }
# #T_d3762_row1_col0, #T_d3762_row1_col1, #T_d3762_row1_col2, #T_d3762_row1_col3, #T_d3762_row1_col4, #T_d3762_row11_col0, #T_d3762_row11_col1, #T_d3762_row11_col2, #T_d3762_row11_col3, #T_d3762_row11_col4, #T_d3762_row12_col0, #T_d3762_row12_col1, #T_d3762_row12_col2, #T_d3762_row12_col3, #T_d3762_row12_col4, #T_d3762_row13_col0, #T_d3762_row13_col1, #T_d3762_row13_col2, #T_d3762_row13_col3, #T_d3762_row13_col4, #T_d3762_row14_col0, #T_d3762_row14_col1, #T_d3762_row14_col2, #T_d3762_row14_col3, #T_d3762_row14_col4, #T_d3762_row17_col0, #T_d3762_row17_col1, #T_d3762_row17_col2, #T_d3762_row17_col3, #T_d3762_row17_col4, #T_d3762_row18_col0, #T_d3762_row18_col1, #T_d3762_row18_col2, #T_d3762_row18_col3, #T_d3762_row18_col4, #T_d3762_row19_col0, #T_d3762_row19_col1, #T_d3762_row19_col2, #T_d3762_row19_col3, #T_d3762_row19_col4, #T_d3762_row24_col0, #T_d3762_row24_col1, #T_d3762_row24_col2, #T_d3762_row24_col3, #T_d3762_row24_col4, #T_d3762_row28_col0, #T_d3762_row28_col1, #T_d3762_row28_col2, #T_d3762_row28_col3, #T_d3762_row28_col4, #T_d3762_row29_col0, #T_d3762_row29_col1, #T_d3762_row29_col2, #T_d3762_row29_col3, #T_d3762_row29_col4, #T_d3762_row31_col0, #T_d3762_row31_col1, #T_d3762_row31_col2, #T_d3762_row31_col3, #T_d3762_row31_col4, #T_d3762_row33_col0, #T_d3762_row33_col1, #T_d3762_row33_col2, #T_d3762_row33_col3, #T_d3762_row33_col4 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_d3762_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chance Type</th>
#       <th class="col_heading level0 col1" >Shooting Percent_TS_True</th>
#       <th class="col_heading level0 col2" >Historical % (TS_True)</th>
#       <th class="col_heading level0 col3" >Cohen_d_TS_True</th>
#       <th class="col_heading level0 col4" >Cohen_d_TS_True_Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3762_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_d3762_row0_col0" class="data row0 col0" >Net Broken Play</td>
#       <td id="T_d3762_row0_col1" class="data row0 col1" >0.42</td>
#       <td id="T_d3762_row0_col2" class="data row0 col2" >0.26</td>
#       <td id="T_d3762_row0_col3" class="data row0 col3" >0.509792</td>
#       <td id="T_d3762_row0_col4" class="data row0 col4" >Large</td>
#     </tr>
#     <tr>
#       <th id="T_d3762_level0_row1" class="row_heading level0 row1" >31</th>
#       <td id="T_d3762_row1_col0" class="data row1 col0" >Slot Line Double</td>
#       <td id="T_d3762_row1_col1" class="data row1 col1" >0.68</td>
#       <td id="T_d3762_row1_col2" class="data row1 col2" >0.2</td>
#       <td id="T_d3762_row1_col3" class="data row1 col3" >0.509792</td>
#       <td id="T_d3762_row1_col4" class="data row1 col4" >Large</td>
#     </tr>
#     <tr>
#       <th id="T_d3762_level0_row2" class="row_heading level0 row2" >35</th>
#       <td id="T_d3762_row2_col0" class="data row2 col0" >Weak Mid % Rebound</td>
#       <td id="T_d3762_row2_col1" class="data row2 col1" >0.62</td>
#       <td id="T_d3762_row2_col2" class="data row2 col2" >0.09</td>
#       <td id="T_d3762_row2_col3" class="data row2 col3" >0.509792</td>
#       <td id="T_d3762_row2_col4" class="data row2 col4" >Large</td>
#     </tr>
#     <tr>
#       <th id="T_d3762_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_d3762_row3_col0" class="data row3 col0" >Goalie Error</td>
#       <td id="T_d3762_row3_col1" class="data row3 col1" >0.79</td>
#       <td id="T_d3762_row3_col2" class="data row3 col2" >0.03</td>
#       <td id="T_d3762_row3_col3" class="data row3 col3" >0.509792</td>
#       <td id="T_d3762_row3_col4" class="data row3 col4" >Large</td>
#     </tr>
#     <tr>
#       <th id="T_d3762_level0_row4" class="row_heading level0 row4" >34</th>
#       <td id="T_d3762_row4_col0" class="data row4 col0" >Strong Mid % Rebound</td>
#       <td id="T_d3762_row4_col1" class="data row4 col1" >0.28</td>
#       <td id="T_d3762_row4_col2" class="data row4 col2" >0.11</td>
#       <td id="T_d3762_row4_col3" class="data row4 col3" >0.509792</td>
#       <td id="T_d3762_row4_col4" class="data row4 col4" >Large</td>
#     </tr>
#     <tr>
#       <th id="T_d3762_level0_row5" class="row_heading level0 row5" >26</th>
#       <td id="T_d3762_row5_col0" class="data row5 col0" >Passed Off Rebound</td>
#       <td id="T_d3762_row5_col1" class="data row5 col1" >0.55</td>
#       <td id="T_d3762_row5_col2" class="data row5 col2" >0.23</td>
#       <td id="T_d3762_row5_col3" class="data row5 col3" >0.509792</td>
#       <td id="T_d3762_row5_col4" class="data row5 col4" >Large</td>
#     </tr>
#     <tr>
#       <th id="T_d3762_level0_row6" class="row_heading level0 row6" >33</th>
#       <td id="T_d3762_row6_col0" class="data row6 col0" >Strong High % Rebound</td>
#       <td id="T_d3762_row6_col1" class="data row6 col1" >0.27</td>
#       <td id="T_d3762_row6_col2" class="data row6 col2" >0.12</td>
#       <td id="T_d3762_row6_col3" class="data row6 col3" >0.509792</td>
#       <td id="T_d3762_row6_col4" class="data row6 col4" >Large</td>
#     </tr>
#     <tr>
#       <th id="T_d3762_level0_row7" class="row_heading level0 row7" >30</th>
#       <td id="T_d3762_row7_col0" class="data row7 col0" >Slot Line Carry</td>
#       <td id="T_d3762_row7_col1" class="data row7 col1" >0.32</td>
#       <td id="T_d3762_row7_col2" class="data row7 col2" >0.3</td>
#       <td id="T_d3762_row7_col3" class="data row7 col3" >0.509792</td>
#       <td id="T_d3762_row7_col4" class="data row7 col4" >Large</td>
#     </tr>
#     <tr>
#       <th id="T_d3762_level0_row8" class="row_heading level0 row8" >29</th>
#       <td id="T_d3762_row8_col0" class="data row8 col0" >Slot Area Screen</td>
#       <td id="T_d3762_row8_col1" class="data row8 col1" >0.41</td>
#       <td id="T_d3762_row8_col2" class="data row8 col2" >0.23</td>
#       <td id="T_d3762_row8_col3" class="data row8 col3" >0.509792</td>
#       <td id="T_d3762_row8_col4" class="data row8 col4" >Large</td>
#     </tr>
#     <tr>
#       <th id="T_d3762_level0_row9" class="row_heading level0 row9" >27</th>
#       <td id="T_d3762_row9_col0" class="data row9 col0" >Screened One Timer</td>
#       <td id="T_d3762_row9_col1" class="data row9 col1" >0.39</td>
#       <td id="T_d3762_row9_col2" class="data row9 col2" >0.55</td>
#       <td id="T_d3762_row9_col3" class="data row9 col3" >0.509792</td>
#       <td id="T_d3762_row9_col4" class="data row9 col4" >Large</td>
#     </tr>
#     <tr>
#       <th id="T_d3762_level0_row10" class="row_heading level0 row10" >19</th>
#       <td id="T_d3762_row10_col0" class="data row10 col0" >Mid % Broken Play</td>
#       <td id="T_d3762_row10_col1" class="data row10 col1" >0.33</td>
#       <td id="T_d3762_row10_col2" class="data row10 col2" >0.36</td>
#       <td id="T_d3762_row10_col3" class="data row10 col3" >0.509792</td>
#       <td id="T_d3762_row10_col4" class="data row10 col4" >Large</td>
#     </tr>
#     <tr>
#       <th id="T_d3762_level0_row11" class="row_heading level0 row11" >1</th>
#       <td id="T_d3762_row11_col0" class="data row11 col0" >Behind the Net To Slot One Timer</td>
#       <td id="
# Shooting Percent Comparison: TS_False Shots
# <style type="text/css">
# #T_1cb4a_row0_col1, #T_1cb4a_row0_col2, #T_1cb4a_row2_col1, #T_1cb4a_row2_col2, #T_1cb4a_row3_col1, #T_1cb4a_row3_col2, #T_1cb4a_row4_col1, #T_1cb4a_row4_col2, #T_1cb4a_row5_col1, #T_1cb4a_row5_col2, #T_1cb4a_row6_col1, #T_1cb4a_row6_col2, #T_1cb4a_row7_col1, #T_1cb4a_row7_col2, #T_1cb4a_row8_col1, #T_1cb4a_row8_col2, #T_1cb4a_row9_col1, #T_1cb4a_row9_col2, #T_1cb4a_row10_col1, #T_1cb4a_row10_col2, #T_1cb4a_row15_col1, #T_1cb4a_row15_col2, #T_1cb4a_row16_col1, #T_1cb4a_row16_col2, #T_1cb4a_row20_col1, #T_1cb4a_row20_col2, #T_1cb4a_row21_col1, #T_1cb4a_row21_col2, #T_1cb4a_row22_col1, #T_1cb4a_row22_col2, #T_1cb4a_row23_col1, #T_1cb4a_row23_col2, #T_1cb4a_row25_col1, #T_1cb4a_row25_col2, #T_1cb4a_row26_col1, #T_1cb4a_row26_col2, #T_1cb4a_row27_col1, #T_1cb4a_row27_col2, #T_1cb4a_row30_col1, #T_1cb4a_row30_col2, #T_1cb4a_row32_col1, #T_1cb4a_row32_col2, #T_1cb4a_row34_col1, #T_1cb4a_row34_col2, #T_1cb4a_row35_col1, #T_1cb4a_row35_col2 {
#   background-color: #f8d7da;
# }
# #T_1cb4a_row1_col0, #T_1cb4a_row1_col1, #T_1cb4a_row1_col2, #T_1cb4a_row1_col3, #T_1cb4a_row1_col4, #T_1cb4a_row11_col0, #T_1cb4a_row11_col1, #T_1cb4a_row11_col2, #T_1cb4a_row11_col3, #T_1cb4a_row11_col4, #T_1cb4a_row12_col0, #T_1cb4a_row12_col1, #T_1cb4a_row12_col2, #T_1cb4a_row12_col3, #T_1cb4a_row12_col4, #T_1cb4a_row13_col0, #T_1cb4a_row13_col1, #T_1cb4a_row13_col2, #T_1cb4a_row13_col3, #T_1cb4a_row13_col4, #T_1cb4a_row14_col0, #T_1cb4a_row14_col1, #T_1cb4a_row14_col2, #T_1cb4a_row14_col3, #T_1cb4a_row14_col4, #T_1cb4a_row17_col0, #T_1cb4a_row17_col1, #T_1cb4a_row17_col2, #T_1cb4a_row17_col3, #T_1cb4a_row17_col4, #T_1cb4a_row18_col0, #T_1cb4a_row18_col1, #T_1cb4a_row18_col2, #T_1cb4a_row18_col3, #T_1cb4a_row18_col4, #T_1cb4a_row19_col0, #T_1cb4a_row19_col1, #T_1cb4a_row19_col2, #T_1cb4a_row19_col3, #T_1cb4a_row19_col4, #T_1cb4a_row24_col0, #T_1cb4a_row24_col1, #T_1cb4a_row24_col2, #T_1cb4a_row24_col3, #T_1cb4a_row24_col4, #T_1cb4a_row28_col0, #T_1cb4a_row28_col1, #T_1cb4a_row28_col2, #T_1cb4a_row28_col3, #T_1cb4a_row28_col4, #T_1cb4a_row29_col0, #T_1cb4a_row29_col1, #T_1cb4a_row29_col2, #T_1cb4a_row29_col3, #T_1cb4a_row29_col4, #T_1cb4a_row31_col0, #T_1cb4a_row31_col1, #T_1cb4a_row31_col2, #T_1cb4a_row31_col3, #T_1cb4a_row31_col4, #T_1cb4a_row33_col0, #T_1cb4a_row33_col1, #T_1cb4a_row33_col2, #T_1cb4a_row33_col3, #T_1cb4a_row33_col4 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_1cb4a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chance Type</th>
#       <th class="col_heading level0 col1" >Shooting Percent_TS_False</th>
#       <th class="col_heading level0 col2" >Historical % (TS_False)</th>
#       <th class="col_heading level0 col3" >Cohen_d_TS_False</th>
#       <th class="col_heading level0 col4" >Cohen_d_TS_False_Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cb4a_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_1cb4a_row0_col0" class="data row0 col0" >Net Broken Play</td>
#       <td id="T_1cb4a_row0_col1" class="data row0 col1" >0.12</td>
#       <td id="T_1cb4a_row0_col2" class="data row0 col2" >0.12</td>
#       <td id="T_1cb4a_row0_col3" class="data row0 col3" >-0.090988</td>
#       <td id="T_1cb4a_row0_col4" class="data row0 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_1cb4a_level0_row1" class="row_heading level0 row1" >31</th>
#       <td id="T_1cb4a_row1_col0" class="data row1 col0" >Slot Line Double</td>
#       <td id="T_1cb4a_row1_col1" class="data row1 col1" >0.41</td>
#       <td id="T_1cb4a_row1_col2" class="data row1 col2" >0.49</td>
#       <td id="T_1cb4a_row1_col3" class="data row1 col3" >-0.090988</td>
#       <td id="T_1cb4a_row1_col4" class="data row1 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_1cb4a_level0_row2" class="row_heading level0 row2" >35</th>
#       <td id="T_1cb4a_row2_col0" class="data row2 col0" >Weak Mid % Rebound</td>
#       <td id="T_1cb4a_row2_col1" class="data row2 col1" >0.38</td>
#       <td id="T_1cb4a_row2_col2" class="data row2 col2" >0.09</td>
#       <td id="T_1cb4a_row2_col3" class="data row2 col3" >-0.090988</td>
#       <td id="T_1cb4a_row2_col4" class="data row2 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_1cb4a_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_1cb4a_row3_col0" class="data row3 col0" >Goalie Error</td>
#       <td id="T_1cb4a_row3_col1" class="data row3 col1" >0.57</td>
#       <td id="T_1cb4a_row3_col2" class="data row3 col2" >0.01</td>
#       <td id="T_1cb4a_row3_col3" class="data row3 col3" >-0.090988</td>
#       <td id="T_1cb4a_row3_col4" class="data row3 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_1cb4a_level0_row4" class="row_heading level0 row4" >34</th>
#       <td id="T_1cb4a_row4_col0" class="data row4 col0" >Strong Mid % Rebound</td>
#       <td id="T_1cb4a_row4_col1" class="data row4 col1" >0.07</td>
#       <td id="T_1cb4a_row4_col2" class="data row4 col2" >0.11</td>
#       <td id="T_1cb4a_row4_col3" class="data row4 col3" >-0.090988</td>
#       <td id="T_1cb4a_row4_col4" class="data row4 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_1cb4a_level0_row5" class="row_heading level0 row5" >26</th>
#       <td id="T_1cb4a_row5_col0" class="data row5 col0" >Passed Off Rebound</td>
#       <td id="T_1cb4a_row5_col1" class="data row5 col1" >0.35</td>
#       <td id="T_1cb4a_row5_col2" class="data row5 col2" >0.55</td>
#       <td id="T_1cb4a_row5_col3" class="data row5 col3" >-0.090988</td>
#       <td id="T_1cb4a_row5_col4" class="data row5 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_1cb4a_level0_row6" class="row_heading level0 row6" >33</th>
#       <td id="T_1cb4a_row6_col0" class="data row6 col0" >Strong High % Rebound</td>
#       <td id="T_1cb4a_row6_col1" class="data row6 col1" >0.09</td>
#       <td id="T_1cb4a_row6_col2" class="data row6 col2" >0.04</td>
#       <td id="T_1cb4a_row6_col3" class="data row6 col3" >-0.090988</td>
#       <td id="T_1cb4a_row6_col4" class="data row6 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_1cb4a_level0_row7" class="row_heading level0 row7" >30</th>
#       <td id="T_1cb4a_row7_col0" class="data row7 col0" >Slot Line Carry</td>
#       <td id="T_1cb4a_row7_col1" class="data row7 col1" >0.14</td>
#       <td id="T_1cb4a_row7_col2" class="data row7 col2" >0.2</td>
#       <td id="T_1cb4a_row7_col3" class="data row7 col3" >-0.090988</td>
#       <td id="T_1cb4a_row7_col4" class="data row7 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_1cb4a_level0_row8" class="row_heading level0 row8" >29</th>
#       <td id="T_1cb4a_row8_col0" class="data row8 col0" >Slot Area Screen</td>
#       <td id="T_1cb4a_row8_col1" class="data row8 col1" >0.24</td>
#       <td id="T_1cb4a_row8_col2" class="data row8 col2" >0.3</td>
#       <td id="T_1cb4a_row8_col3" class="data row8 col3" >-0.090988</td>
#       <td id="T_1cb4a_row8_col4" class="data row8 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_1cb4a_level0_row9" class="row_heading level0 row9" >27</th>
#       <td id="T_1cb4a_row9_col0" class="data row9 col0" >Screened One Timer</td>
#       <td id="T_1cb4a_row9_col1" class="data row9 col1" >0.26</td>
#       <td id="T_1cb4a_row9_col2" class="data row9 col2" >0.34</td>
#       <td id="T_1cb4a_row9_col3" class="data row9 col3" >-0.090988</td>
#       <td id="T_1cb4a_row9_col4" class="data row9 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_1cb4a_level0_row10" class="row_heading level0 row10" >19</th>
#       <td id="T_1cb4a_row10_col0" class="data row10 col0" >Mid % Broken Play</td>
#       <td id="T_1cb4a_row10_col1" class="data row10 col1" >0.21</td>
#       <td id="T_1cb4a_row10_col2" class="data row10 col2" >0.26</td>
#       <td id="T_1cb4a_row10_col3" class="data row10 col3" >-0.090988</td>
#       <td id="T_1cb4a_row10_col4" class="data row10 col4" >Small</td>
#     </tr>
#     <tr>
#       <th id="T_1cb4a_level0_row11" class="row_heading level0 row11" >1</th>
#       <td id="T_1cb4a_row11_col0" class="data row11 col0" >Behind the Net To Slot One Timer</td>
